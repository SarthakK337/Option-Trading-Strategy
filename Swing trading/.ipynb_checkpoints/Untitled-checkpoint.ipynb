# %%
import requests
import pandas as pd

# %%
headers={ 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
session=requests.session()
session.get("http://www1.nseindia.com", headers = headers)
# Out:
# <Response [200]>

# %%
def Volume(symbol,Time,dataType):
    url="https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol="+symbol+"&segmentLink=3&symbolCount=2&series=ALL&dateRange="+Time+"&fromDate=&toDate=&dataType="+dataType
    data = session.get(url, headers =headers)
    df=pd.read_html(data.content)[0]
    return df

# %%
Nifty100=pd.read_csv("ind_nifty100list.csv")

# %%
Nifty100
# Out:
#                                   Company Name                    Industry  \
# 0                                     ACC Ltd.      Construction Materials
# 1                       Adani Enterprises Ltd.             Metals & Mining
# 2                      Adani Green Energy Ltd.                       Power
# 3   Adani Ports and Special Economic Zone Ltd.                    Services
# 4                         Adani Total Gas Ltd.  Oil Gas & Consumable Fuels
# ..                                         ...                         ...
# 95                       UltraTech Cement Ltd.      Construction Materials
# 96                         United Spirits Ltd.  Fast Moving Consumer Goods
# 97                                Vedanta Ltd.             Metals & Mining
# 98                                  Wipro Ltd.      Information Technology
# 99                                 Zomato Ltd.           Consumer Services
#
#         Symbol Series     ISIN Code      Proper       Lower
# ...

# %%
for i in Nifty100["Lower"]:
    headers={ 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
    session=requests.session()
    session.get("http://www1.nseindia.com", headers = headers)
    try:
        print(type(Volume(i,"1month","PRICEVOLUMEDELIVERABLE","1")),i)
    except Exception as e:
        print(type(Volume(i,"1month","PRICEVOLUMEDELIVERABLE","2")),i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-2eda9a52369e> in <module>
#       5     try:
# ----> 6         print(type(Volume(i,"1month","PRICEVOLUMEDELIVERABLE","1")),i)
#       7     except Exception as e:
#
# <ipython-input-101-cd1f13451bcf> in Volume(symbol, Time, dataType, symbolCount)
#       3     data = session.get(url, headers =headers)
# ----> 4     df=pd.read_html(data.content)[0]
#       5     return df
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1112
# -> 1113     return _parse(
# ...

# %%
Volume("acc","1month","PRICEVOLUMEDELIVERABLE","1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-6733bce09ec1> in <module>
# ----> 1 Volume("acc","1month","PRICEVOLUMEDELIVERABLE","1")
#
# <ipython-input-101-cd1f13451bcf> in Volume(symbol, Time, dataType, symbolCount)
#       2     url="https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol="+symbol+"&segmentLink=3&symbolCount="+symbolCount+"&series=ALL&dateRange="+Time+"&fromDate=&toDate=&dataType="+dataType
#       3     data = session.get(url, headers =headers)
# ----> 4     df=pd.read_html(data.content)[0]
#       5     return df
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
Volume("acc","1month","PRICEVOLUMEDELIVERABLE","2")
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     ACC     BL  03-Oct-2022     2254.80     2415.65     2415.65    2415.65
# 1     ACC     EQ  03-Oct-2022     2415.65     2419.80     2434.90    2288.00
# 2     ACC     EQ  04-Oct-2022     2301.30     2355.00     2373.30    2288.05
# 3     ACC     EQ  06-Oct-2022     2359.65     2371.45     2397.75    2344.00
# 4     ACC     EQ  07-Oct-2022     2381.75     2370.15     2400.00    2350.00
# 5     ACC     EQ  10-Oct-2022     2384.75     2350.00     2399.90    2350.00
# 6     ACC     EQ  11-Oct-2022     2369.25     2375.05     2376.75    2305.70
# 7     ACC     EQ  12-Oct-2022     2311.65     2318.00     2339.40    2282.10
# 8     ACC     EQ  13-Oct-2022     2316.80     2316.00     2318.00    2242.90
# 9     ACC     EQ  14-Oct-2022     2253.90     2272.00     2285.95    2237.05
# 10    ACC     EQ  17-Oct-2022     2243.65     2232.00     2285.05    2205.30
# ...

# %%
def Volume(symbol,Time,dataType,symbolCount):
    url="https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol="+symbol+"&segmentLink=3&symbolCount="+symbolCount+"&series=ALL&dateRange="+Time+"&fromDate=&toDate=&dataType="+dataType
    data = session.get(url, headers =headers)
    df=pd.read_html(data.content)[0]
    return df

# %%
'https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol=tcs&segmentLink=3&symbolCount=2&series=ALL&dateRange=1month&fromDate=&toDate=&dataType=PRICEVOLUMEDELIVERABLE'
