# %%
import requests
import pandas as pd

class NSE:
    def __init__(self):
        self.headers={ 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
        self.session=requests.session()
        self.session.get("http://nseindia.com", headers = self.headers)



    def option_data(self, symbol, indices=False):
        symbol=symbol.replace(',' ,'%20').replace('&', '%26')
        if not indices:
            url = 'https://www.nseindia.com/api/option-chain-equities?symbol=' + symbol
        else:
            url = 'https://www.nseindia.com/api/option-chain-indices?symbole=' + symbol
        data = self.session.get(url, headers =self.headers).json()["records"]["data"]
        my_df = []
        for i in data:
            for k, v in i.items():
                if k =="CE" or k == "PE":
                    info = v
                    info["instrumentType"] = k
                    my_df.append(info)
        df = pd.DataFrame(my_df)
        df = df.set_index("identifier", drop=True)
        return df

# %%
headers={ 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
session=requests.session()
session.get("http://nseindia.com", headers = headers)
# Out:
# <Response [200]>

# %%
def option_data(symbol, indices=False):
    symbol=symbol.replace(',' ,'%20').replace('&', '%26')
    if not indices:
        url = 'https://www.nseindia.com/api/option-chain-equities?symbol=' + symbol
    else:
        url = 'https://www.nseindia.com/api/option-chain-indices?symbole=' + symbol
    data = session.get(url, headers =headers).json()["records"]["data"]
    my_df = []
    for i in data:
        for k, v in i.items():
            if k =="CE" or k == "PE":
                info = v
                info["instrumentType"] = k
                my_df.append(info)
    df = pd.DataFrame(my_df)
    df = df.set_index("identifier", drop=True)
    return df

# %%
option_data("TCS")
# Out:
#                               strikePrice   expiryDate underlying  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00         2360  24-Nov-2022        TCS
# OPTSTKTCS24-11-2022CE2360.00         2360  24-Nov-2022        TCS
# OPTSTKTCS29-12-2022CE2360.00         2360  29-Dec-2022        TCS
# OPTSTKTCS29-12-2022CE2380.00         2380  29-Dec-2022        TCS
# OPTSTKTCS24-11-2022PE2380.00         2380  24-Nov-2022        TCS
# ...                                   ...          ...        ...
# OPTSTKTCS24-11-2022PE4460.00         4460  24-Nov-2022        TCS
# OPTSTKTCS24-11-2022PE4480.00         4480  24-Nov-2022        TCS
# OPTSTKTCS24-11-2022CE4480.00         4480  24-Nov-2022        TCS
# OPTSTKTCS24-11-2022CE4500.00         4500  24-Nov-2022        TCS
# OPTSTKTCS24-11-2022PE4500.00         4500  24-Nov-2022        TCS
#
#                               openInterest  changeinOpenInterest  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00           0.0                   0.0
# OPTSTKTCS24-11-2022CE2360.00           0.0                   0.0
# OPTSTKTCS29-12-2022CE2360.00           0.0                   0.0
# OPTSTKTCS29-12-2022CE2380.00           0.0                   0.0
# OPTSTKTCS24-11-2022PE2380.00           0.0                   0.0
# ...                                    ...                   ...
# OPTSTKTCS24-11-2022PE4460.00           0.0                   0.0
# OPTSTKTCS24-11-2022PE4480.00           0.0                   0.0
# OPTSTKTCS24-11-2022CE4480.00           0.0                   0.0
# OPTSTKTCS24-11-2022CE4500.00           0.0                   0.0
# OPTSTKTCS24-11-2022PE4500.00           0.0                   0.0
#
#                               pchangeinOpenInterest  totalTradedVolume  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00                    0.0                0.0
# OPTSTKTCS24-11-2022CE2360.00                    0.0                0.0
# OPTSTKTCS29-12-2022CE2360.00                    0.0                0.0
# OPTSTKTCS29-12-2022CE2380.00                    0.0                0.0
# OPTSTKTCS24-11-2022PE2380.00                    0.0                0.0
# ...                                             ...                ...
# OPTSTKTCS24-11-2022PE4460.00                    0.0                0.0
# OPTSTKTCS24-11-2022PE4480.00                    0.0                0.0
# OPTSTKTCS24-11-2022CE4480.00                    0.0                0.0
# OPTSTKTCS24-11-2022CE4500.00                    0.0                0.0
# OPTSTKTCS24-11-2022PE4500.00                    0.0                0.0
#
#                               impliedVolatility  lastPrice  change  pChange  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022CE2360.00                0.0        0.0     0.0      0.0
# OPTSTKTCS29-12-2022CE2360.00                0.0        0.0     0.0      0.0
# OPTSTKTCS29-12-2022CE2380.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022PE2380.00                0.0        0.0     0.0      0.0
# ...                                         ...        ...     ...      ...
# OPTSTKTCS24-11-2022PE4460.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022PE4480.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022CE4480.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022CE4500.00                0.0        0.0     0.0      0.0
# OPTSTKTCS24-11-2022PE4500.00                0.0        0.0     0.0      0.0
#
#                               totalBuyQuantity  totalSellQuantity  bidQty  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00              3000                  0    3000
# OPTSTKTCS24-11-2022CE2360.00              3000               3000    3000
# OPTSTKTCS29-12-2022CE2360.00              3000               3000    3000
# OPTSTKTCS29-12-2022CE2380.00              3000               3000    3000
# OPTSTKTCS24-11-2022PE2380.00              3000                  0    3000
# ...                                        ...                ...     ...
# OPTSTKTCS24-11-2022PE4460.00              3000               3000    3000
# OPTSTKTCS24-11-2022PE4480.00              3000               3000    3000
# OPTSTKTCS24-11-2022CE4480.00              3000                  0    3000
# OPTSTKTCS24-11-2022CE4500.00              3000                600    3000
# OPTSTKTCS24-11-2022PE4500.00              3000               3000    3000
#
#                               bidprice  askQty  askPrice  underlyingValue  \
# identifier
# OPTSTKTCS24-11-2022PE2360.00      0.10       0      0.00             3259
# OPTSTKTCS24-11-2022CE2360.00    803.00    3000    972.25             3259
# OPTSTKTCS29-12-2022CE2360.00    820.35    3000   1014.35             3259
# OPTSTKTCS29-12-2022CE2380.00    802.15    3000    992.00             3259
# OPTSTKTCS24-11-2022PE2380.00      0.10       0      0.00             3259
# ...                                ...     ...       ...              ...
# OPTSTKTCS24-11-2022PE4460.00   1096.25    3000   1337.00             3259
# OPTSTKTCS24-11-2022PE4480.00   1114.00    3000   1359.10             3259
# OPTSTKTCS24-11-2022CE4480.00      0.10       0      0.00             3259
# OPTSTKTCS24-11-2022CE4500.00      0.10     600      3.00             3259
# OPTSTKTCS24-11-2022PE4500.00   1131.80    3000   1379.25             3259
#
#                              instrumentType
# identifier
# OPTSTKTCS24-11-2022PE2360.00             PE
# OPTSTKTCS24-11-2022CE2360.00             CE
# OPTSTKTCS29-12-2022CE2360.00             CE
# OPTSTKTCS29-12-2022CE2380.00             CE
# OPTSTKTCS24-11-2022PE2380.00             PE
# ...                                     ...
# OPTSTKTCS24-11-2022PE4460.00             PE
# OPTSTKTCS24-11-2022PE4480.00             PE
# OPTSTKTCS24-11-2022CE4480.00             CE
# OPTSTKTCS24-11-2022CE4500.00             CE
# OPTSTKTCS24-11-2022PE4500.00             PE
#
# [391 rows x 19 columns]

# %%
def Volume(symbol,Time,dataType):
    url="https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol="+symbol+"&segmentLink=3&symbolCount=2&series=ALL&dateRange="+Time+"&fromDate=&toDate=&dataType="+dataType
    data = session.get(url, headers =headers)
    df=pd.read_html(data.content)[0]
    return df

# %%
Volume("acc","1month","PRICEVOLUMEDELIVERABLE")
