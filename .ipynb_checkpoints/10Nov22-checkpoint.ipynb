# %%
import numpy as np #The Numpy numerical computing library
import pandas as pd #The Pandas data science library
import requests #The requests library for HTTP requests in Python
import xlsxwriter #The XlsxWriter libarary for 
import math #The Python math module
import pandas as pd
import json
from pandas import json_normalize

# %% [raw]
# df=pd.read_csv("option-chain-ED-NIFTY-27-Oct-2022.csv")

# %% [raw]
# df

# %%
import requests
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36','Accept-Encoding': 'gzip, deflate, br','Accept-Language': 'en-US,en;q=0.9,hi;q=0.8'}
url = "https://www.nseindia.com/api/option-chain-indices?symbol=BANKNIFTY"
json_obj = requests.get(url, headers = headers).json()

# %%
json_obj
# Out:
# {'records': {'expiryDates': ['03-Nov-2022',
#    '10-Nov-2022',
#    '17-Nov-2022',
#    '24-Nov-2022',
#    '01-Dec-2022',
#    '29-Dec-2022',
#    '25-Jan-2023',
#    '30-Mar-2023',
#    '29-Jun-2023',
#    '28-Sep-2023'],
#   'data': [{'strikePrice': 25500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 25500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1850,
#      'totalSellQuantity': 925,
#      'bidQty': 75,
#      'bidprice': 15121.6,
#      'askQty': 50,
#      'askPrice': 16379.35,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 5100,
#      'totalSellQuantity': 0,
#      'bidQty': 25,
#      'bidprice': 1.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 25500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1000,
#      'totalSellQuantity': 0,
#      'bidQty': 100,
#      'bidprice': 0.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 25500,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 25500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 27000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 75,
#      'bidprice': 0.3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 27000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 27000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE27000.00',
#      'openInterest': 109,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 7250,
#      'totalSellQuantity': 0,
#      'bidQty': 3000,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 27000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1200,
#      'totalSellQuantity': 975,
#      'bidQty': 325,
#      'bidprice': 13781.15,
#      'askQty': 100,
#      'askPrice': 14814.05,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 27000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 28500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 28500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE28500.00',
#      'openInterest': 64,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8425,
#      'totalSellQuantity': 0,
#      'bidQty': 5200,
#      'bidprice': 3.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 28500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 925,
#      'bidQty': 875,
#      'bidprice': 12354.25,
#      'askQty': 50,
#      'askPrice': 13443.95,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 28500,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 28500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE28500.00',
#      'openInterest': 3,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 29000,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 29000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE29000.00',
#      'openInterest': 13,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 45250,
#      'totalSellQuantity': 0,
#      'bidQty': 2000,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 29000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE29000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1575,
#      'totalSellQuantity': 1400,
#      'bidQty': 200,
#      'bidprice': 11862.6,
#      'askQty': 25,
#      'askPrice': 12390.15,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 29500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 29500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE29500.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2275,
#      'totalSellQuantity': 1425,
#      'bidQty': 500,
#      'bidprice': 11370.4,
#      'askQty': 50,
#      'askPrice': 11887.25,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 29500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE29500.00',
#      'openInterest': 24,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 43850,
#      'totalSellQuantity': 0,
#      'bidQty': 1800,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2025,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE30000.00',
#      'openInterest': 156,
#      'changeinOpenInterest': 9,
#      'pchangeinOpenInterest': 6.122448979591836,
#      'totalTradedVolume': 42,
#      'impliedVolatility': 50.67,
#      'lastPrice': 6.75,
#      'change': -0.5499999999999998,
#      'pChange': -7.534246575342464,
#      'totalBuyQuantity': 2925,
#      'totalSellQuantity': 2700,
#      'bidQty': 125,
#      'bidprice': 6.25,
#      'askQty': 50,
#      'askPrice': 7.6,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 30000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE30000.00',
#      'openInterest': 99,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1750,
#      'totalSellQuantity': 1575,
#      'bidQty': 250,
#      'bidprice': 10915.3,
#      'askQty': 125,
#      'askPrice': 11372.4,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE30000.00',
#      'openInterest': 1412,
#      'changeinOpenInterest': 6,
#      'pchangeinOpenInterest': 0.4267425320056899,
#      'totalTradedVolume': 9,
#      'impliedVolatility': 31.26,
#      'lastPrice': 4.9,
#      'change': -17.25,
#      'pChange': -77.87810383747178,
#      'totalBuyQuantity': 39400,
#      'totalSellQuantity': 0,
#      'bidQty': 36800,
#      'bidprice': 4.9,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 30000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE30000.00',
#      'openInterest': 14,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1375,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9939.7,
#      'askQty': 875,
#      'askPrice': 12721.6,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 25,
#      'bidQty': 900,
#      'bidprice': 1.25,
#      'askQty': 25,
#      'askPrice': 150,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30500,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30500,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE30500.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 40775,
#      'totalSellQuantity': 0,
#      'bidQty': 2700,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1950,
#      'totalSellQuantity': 1375,
#      'bidQty': 575,
#      'bidprice': 10402.3,
#      'askQty': 875,
#      'askPrice': 11761.4,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30500,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE30500.00',
#      'openInterest': 47926,
#      'changeinOpenInterest': 7756,
#      'pchangeinOpenInterest': 19.307941249688824,
#      'totalTradedVolume': 144876,
#      'impliedVolatility': 184.01,
#      'lastPrice': 0.85,
#      'change': -0.4,
#      'pChange': -32,
#      'totalBuyQuantity': 342625,
#      'totalSellQuantity': 175675,
#      'bidQty': 2175,
#      'bidprice': 0.8,
#      'askQty': 20175,
#      'askPrice': 0.85,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4550,
#      'totalSellQuantity': 3675,
#      'bidQty': 125,
#      'bidprice': 10558.2,
#      'askQty': 500,
#      'askPrice': 10762.2,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30500,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2175,
#      'totalSellQuantity': 2150,
#      'bidQty': 25,
#      'bidprice': 10582.75,
#      'askQty': 25,
#      'askPrice': 10912.4,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE30500.00',
#      'openInterest': 32,
#      'changeinOpenInterest': 32,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 34,
#      'impliedVolatility': 72.22,
#      'lastPrice': 2.75,
#      'change': 1.15,
#      'pChange': 71.87499999999999,
#      'totalBuyQuantity': 50600,
#      'totalSellQuantity': 1400,
#      'bidQty': 500,
#      'bidprice': 2.15,
#      'askQty': 250,
#      'askPrice': 2.9,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 30500,
#     'expiryDate': '17-Nov-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1850,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.15,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9902.7,
#      'askQty': 875,
#      'askPrice': 11840.4,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31000,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2175,
#      'totalSellQuantity': 2150,
#      'bidQty': 25,
#      'bidprice': 10100.4,
#      'askQty': 25,
#      'askPrice': 10429.2,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE31000.00',
#      'openInterest': 175,
#      'changeinOpenInterest': 75,
#      'pchangeinOpenInterest': 75,
#      'totalTradedVolume': 119,
#      'impliedVolatility': 68.13,
#      'lastPrice': 2.65,
#      'change': 0.1499999999999999,
#      'pChange': 5.9999999999999964,
#      'totalBuyQuantity': 50175,
#      'totalSellQuantity': 3125,
#      'bidQty': 75,
#      'bidprice': 2.2,
#      'askQty': 500,
#      'askPrice': 2.9,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31000,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9446.7,
#      'askQty': 875,
#      'askPrice': 11270.5,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3200,
#      'totalSellQuantity': 0,
#      'bidQty': 800,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31000,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE31000.00',
#      'openInterest': 32,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2325,
#      'totalSellQuantity': 1425,
#      'bidQty': 50,
#      'bidprice': 10048.75,
#      'askQty': 50,
#      'askPrice': 10379.95,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE31000.00',
#      'openInterest': 155,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 42.32,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 46875,
#      'totalSellQuantity': 0,
#      'bidQty': 3450,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31000,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1225,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31000,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE31000.00',
#      'openInterest': 14297,
#      'changeinOpenInterest': 1376,
#      'pchangeinOpenInterest': 10.649330547171271,
#      'totalTradedVolume': 66107,
#      'impliedVolatility': 174.68,
#      'lastPrice': 0.85,
#      'change': -0.4,
#      'pChange': -32,
#      'totalBuyQuantity': 229975,
#      'totalSellQuantity': 33700,
#      'bidQty': 23000,
#      'bidprice': 0.8,
#      'askQty': 8800,
#      'askPrice': 0.85,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE31000.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3675,
#      'totalSellQuantity': 4425,
#      'bidQty': 125,
#      'bidprice': 10046.95,
#      'askQty': 750,
#      'askPrice': 10285.3,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1000,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1825,
#      'totalSellQuantity': 925,
#      'bidQty': 50,
#      'bidprice': 9328.9,
#      'askQty': 50,
#      'askPrice': 10346.6,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE31500.00',
#      'openInterest': 279,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 6,
#      'impliedVolatility': 31.94,
#      'lastPrice': 19.95,
#      'change': -8.850000000000001,
#      'pChange': -30.729166666666668,
#      'totalBuyQuantity': 4250,
#      'totalSellQuantity': 0,
#      'bidQty': 1075,
#      'bidprice': 19.95,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '25-Jan-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE31500.00',
#      'openInterest': 14,
#      'changeinOpenInterest': 14,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 17,
#      'impliedVolatility': 30.2,
#      'lastPrice': 46,
#      'change': 8.350000000000001,
#      'pChange': 22.17795484727756,
#      'totalBuyQuantity': 2025,
#      'totalSellQuantity': 125,
#      'bidQty': 100,
#      'bidprice': 45.95,
#      'askQty': 25,
#      'askPrice': 50,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 350,
#      'totalSellQuantity': 0,
#      'bidQty': 350,
#      'bidprice': 8547.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3675,
#      'totalSellQuantity': 3675,
#      'bidQty': 125,
#      'bidprice': 9547.75,
#      'askQty': 500,
#      'askPrice': 9762.15,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE31500.00',
#      'openInterest': 1712,
#      'changeinOpenInterest': -86,
#      'pchangeinOpenInterest': -4.783092324805339,
#      'totalTradedVolume': 22152,
#      'impliedVolatility': 164.69,
#      'lastPrice': 0.8,
#      'change': -0.44999999999999996,
#      'pChange': -36,
#      'totalBuyQuantity': 97625,
#      'totalSellQuantity': 22725,
#      'bidQty': 2225,
#      'bidprice': 0.8,
#      'askQty': 3600,
#      'askPrice': 0.85,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2150,
#      'totalSellQuantity': 2150,
#      'bidQty': 25,
#      'bidprice': 9610.95,
#      'askQty': 750,
#      'askPrice': 10008.7,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 35125,
#      'totalSellQuantity': 0,
#      'bidQty': 100,
#      'bidprice': 3,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 8976.9,
#      'askQty': 875,
#      'askPrice': 10765.7,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1700,
#      'totalSellQuantity': 0,
#      'bidQty': 800,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 31500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE31500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1425,
#      'totalSellQuantity': 1400,
#      'bidQty': 500,
#      'bidprice': 9420.7,
#      'askQty': 25,
#      'askPrice': 9914.4,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE31500.00',
#      'openInterest': 12,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 34800,
#      'totalSellQuantity': 0,
#      'bidQty': 3300,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 32875,
#      'totalSellQuantity': 0,
#      'bidQty': 1150,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2150,
#      'totalSellQuantity': 2175,
#      'bidQty': 25,
#      'bidprice': 9107.25,
#      'askQty': 25,
#      'askPrice': 9343.3,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4050,
#      'totalSellQuantity': 4800,
#      'bidQty': 875,
#      'bidprice': 9102.95,
#      'askQty': 750,
#      'askPrice': 9286.7,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE32000.00',
#      'openInterest': 2418,
#      'changeinOpenInterest': -22,
#      'pchangeinOpenInterest': -0.9016393442622951,
#      'totalTradedVolume': 17684,
#      'impliedVolatility': 156.38,
#      'lastPrice': 0.85,
#      'change': -0.4,
#      'pChange': -32,
#      'totalBuyQuantity': 100700,
#      'totalSellQuantity': 21625,
#      'bidQty': 2100,
#      'bidprice': 0.8,
#      'askQty': 1025,
#      'askPrice': 0.85,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 8520.9,
#      'askQty': 875,
#      'askPrice': 10232.75,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1700,
#      'totalSellQuantity': 0,
#      'bidQty': 800,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE32000.00',
#      'openInterest': 26,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 4,
#      'totalTradedVolume': 2,
#      'impliedVolatility': 0,
#      'lastPrice': 9200,
#      'change': -100,
#      'pChange': -1.0752688172043012,
#      'totalBuyQuantity': 2575,
#      'totalSellQuantity': 2325,
#      'bidQty': 125,
#      'bidprice': 9140.6,
#      'askQty': 25,
#      'askPrice': 9340.4,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE32000.00',
#      'openInterest': 1117,
#      'changeinOpenInterest': -37,
#      'pchangeinOpenInterest': -3.2062391681109186,
#      'totalTradedVolume': 78,
#      'impliedVolatility': 42.16,
#      'lastPrice': 8,
#      'change': -0.34999999999999964,
#      'pChange': -4.191616766467062,
#      'totalBuyQuantity': 2525,
#      'totalSellQuantity': 5225,
#      'bidQty': 100,
#      'bidprice': 6.6,
#      'askQty': 25,
#      'askPrice': 8.5,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32000,
#     'expiryDate': '25-Jan-2023',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE32000.00',
#      'openInterest': 2,
#      'changeinOpenInterest': 2,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 3,
#      'impliedVolatility': 29.84,
#      'lastPrice': 55,
#      'change': 3.75,
#      'pChange': 7.317073170731707,
#      'totalBuyQuantity': 2400,
#      'totalSellQuantity': 125,
#      'bidQty': 900,
#      'bidprice': 5.2,
#      'askQty': 25,
#      'askPrice': 60,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 350,
#      'totalSellQuantity': 0,
#      'bidQty': 350,
#      'bidprice': 8047.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1525,
#      'totalSellQuantity': 1375,
#      'bidQty': 150,
#      'bidprice': 8434.8,
#      'askQty': 500,
#      'askPrice': 9354.55,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE32500.00',
#      'openInterest': 26,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 47950,
#      'totalSellQuantity': 0,
#      'bidQty': 2850,
#      'bidprice': 3.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE32500.00',
#      'openInterest': 60,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2725,
#      'totalSellQuantity': 400,
#      'bidQty': 25,
#      'bidprice': 21,
#      'askQty': 100,
#      'askPrice': 39,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 900,
#      'bidQty': 25,
#      'bidprice': 8427.05,
#      'askQty': 25,
#      'askPrice': 9165.3,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '25-Jan-2023',
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 350,
#      'totalSellQuantity': 0,
#      'bidQty': 350,
#      'bidprice': 7547.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2400,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 5.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '17-Nov-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1700,
#      'totalSellQuantity': 0,
#      'bidQty': 800,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 8139.2,
#      'askQty': 875,
#      'askPrice': 9646.9,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 39575,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.35,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2150,
#      'totalSellQuantity': 2150,
#      'bidQty': 750,
#      'bidprice': 8616.9,
#      'askQty': 25,
#      'askPrice': 8963.85,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 32500,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
# ...
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE43800.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4950,
#      'totalSellQuantity': 5050,
#      'bidQty': 100,
#      'bidprice': 2550.75,
#      'askQty': 100,
#      'askPrice': 2696.4,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 43800,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE43800.00',
#      'openInterest': 4896,
#      'changeinOpenInterest': -387,
#      'pchangeinOpenInterest': -7.325383304940375,
#      'totalTradedVolume': 37035,
#      'impliedVolatility': 48.93,
#      'lastPrice': 2.35,
#      'change': -1.0499999999999998,
#      'pChange': -30.882352941176467,
#      'totalBuyQuantity': 138050,
#      'totalSellQuantity': 17050,
#      'bidQty': 500,
#      'bidprice': 2.35,
#      'askQty': 1625,
#      'askPrice': 2.4,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 43900,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 43900,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE43900.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4850,
#      'totalSellQuantity': 4975,
#      'bidQty': 25,
#      'bidprice': 2651.25,
#      'askQty': 25,
#      'askPrice': 2796.4,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 43900,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE43900.00',
#      'openInterest': 3275,
#      'changeinOpenInterest': 351,
#      'pchangeinOpenInterest': 12.004103967168263,
#      'totalTradedVolume': 32594,
#      'impliedVolatility': 50.6,
#      'lastPrice': 2.35,
#      'change': -1,
#      'pChange': -29.850746268656714,
#      'totalBuyQuantity': 151425,
#      'totalSellQuantity': 12475,
#      'bidQty': 500,
#      'bidprice': 2.35,
#      'askQty': 725,
#      'askPrice': 2.4,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44000,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44000.00',
#      'openInterest': 62406,
#      'changeinOpenInterest': -1816,
#      'pchangeinOpenInterest': -2.8276914452991186,
#      'totalTradedVolume': 346850,
#      'impliedVolatility': 51.91,
#      'lastPrice': 2.35,
#      'change': -0.9499999999999997,
#      'pChange': -28.78787878787878,
#      'totalBuyQuantity': 355175,
#      'totalSellQuantity': 42175,
#      'bidQty': 21225,
#      'bidprice': 2.3,
#      'askQty': 3875,
#      'askPrice': 2.35,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44000.00',
#      'openInterest': 10,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8575,
#      'totalSellQuantity': 7425,
#      'bidQty': 125,
#      'bidprice': 2771.25,
#      'askQty': 125,
#      'askPrice': 2849.8,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44100,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 44100,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44100.00',
#      'openInterest': 2727,
#      'changeinOpenInterest': -1270,
#      'pchangeinOpenInterest': -31.773830372779585,
#      'totalTradedVolume': 26318,
#      'impliedVolatility': 53.56,
#      'lastPrice': 2.25,
#      'change': -0.7999999999999998,
#      'pChange': -26.22950819672131,
#      'totalBuyQuantity': 147575,
#      'totalSellQuantity': 14200,
#      'bidQty': 950,
#      'bidprice': 2.25,
#      'askQty': 2275,
#      'askPrice': 2.3,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 44100,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44100.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 5175,
#      'totalSellQuantity': 4975,
#      'bidQty': 25,
#      'bidprice': 2799.75,
#      'askQty': 25,
#      'askPrice': 2996.5,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44200,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 44200,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44200.00',
#      'openInterest': 2681,
#      'changeinOpenInterest': -948,
#      'pchangeinOpenInterest': -26.12289887021218,
#      'totalTradedVolume': 20818,
#      'impliedVolatility': 54.7,
#      'lastPrice': 2.15,
#      'change': -0.8500000000000001,
#      'pChange': -28.33333333333334,
#      'totalBuyQuantity': 161875,
#      'totalSellQuantity': 10800,
#      'bidQty': 1275,
#      'bidprice': 2.15,
#      'askQty': 400,
#      'askPrice': 2.2,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 44200,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44200.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4250,
#      'totalSellQuantity': 4050,
#      'bidQty': 900,
#      'bidprice': 2921.8,
#      'askQty': 900,
#      'askPrice': 3085.05,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44300,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 44300,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44300.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4250,
#      'totalSellQuantity': 4050,
#      'bidQty': 900,
#      'bidprice': 3027.3,
#      'askQty': 900,
#      'askPrice': 3185.7,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 44300,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44300.00',
#      'openInterest': 8317,
#      'changeinOpenInterest': -4,
#      'pchangeinOpenInterest': -0.04807114529503666,
#      'totalTradedVolume': 41282,
#      'impliedVolatility': 55.93,
#      'lastPrice': 2.05,
#      'change': -0.9000000000000004,
#      'pChange': -30.508474576271194,
#      'totalBuyQuantity': 134175,
#      'totalSellQuantity': 14350,
#      'bidQty': 2900,
#      'bidprice': 2,
#      'askQty': 25,
#      'askPrice': 2.05,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44400,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 44400,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44400.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4250,
#      'totalSellQuantity': 4050,
#      'bidQty': 900,
#      'bidprice': 3125.15,
#      'askQty': 900,
#      'askPrice': 3285.05,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 44400,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44400.00',
#      'openInterest': 3142,
#      'changeinOpenInterest': 211,
#      'pchangeinOpenInterest': 7.198908222449676,
#      'totalTradedVolume': 22802,
#      'impliedVolatility': 56.98,
#      'lastPrice': 2,
#      'change': -0.8500000000000001,
#      'pChange': -29.824561403508774,
#      'totalBuyQuantity': 141400,
#      'totalSellQuantity': 10075,
#      'bidQty': 1275,
#      'bidprice': 2,
#      'askQty': 50,
#      'askPrice': 2.05,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44500,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 44500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 7325,
#      'totalSellQuantity': 6575,
#      'bidQty': 750,
#      'bidprice': 3228.9,
#      'askQty': 125,
#      'askPrice': 3325.7,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 44500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44500.00',
#      'openInterest': 48233,
#      'changeinOpenInterest': 3973,
#      'pchangeinOpenInterest': 8.976502485314054,
#      'totalTradedVolume': 171546,
#      'impliedVolatility': 59.35,
#      'lastPrice': 2.35,
#      'change': -0.8500000000000001,
#      'pChange': -26.5625,
#      'totalBuyQuantity': 209050,
#      'totalSellQuantity': 37225,
#      'bidQty': 775,
#      'bidprice': 2.3,
#      'askQty': 10925,
#      'askPrice': 2.35,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 44600,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 44600,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE44600.00',
#      'openInterest': 1317,
#      'changeinOpenInterest': -412,
#      'pchangeinOpenInterest': -23.828802776171198,
#      'totalTradedVolume': 24840,
#      'impliedVolatility': 60.09,
#      'lastPrice': 2.1,
#      'change': -0.8999999999999999,
#      'pChange': -30,
#      'totalBuyQuantity': 132425,
#      'totalSellQuantity': 10400,
#      'bidQty': 50,
#      'bidprice': 2.05,
#      'askQty': 2400,
#      'askPrice': 2.1,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 44600,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE44600.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4250,
#      'totalSellQuantity': 4050,
#      'bidQty': 900,
#      'bidprice': 3309.6,
#      'askQty': 900,
#      'askPrice': 3484.05,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 45000,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 45000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE45000.00',
#      'openInterest': 28503,
#      'changeinOpenInterest': 256,
#      'pchangeinOpenInterest': 0.9062909335504655,
#      'totalTradedVolume': 141364,
#      'impliedVolatility': 65.23,
#      'lastPrice': 1.85,
#      'change': -0.7999999999999998,
#      'pChange': -30.188679245283012,
#      'totalBuyQuantity': 257850,
#      'totalSellQuantity': 28700,
#      'bidQty': 8475,
#      'bidprice': 1.8,
#      'askQty': 325,
#      'askPrice': 1.85,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 45000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE45000.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6450,
#      'totalSellQuantity': 6600,
#      'bidQty': 3275,
#      'bidprice': 3734.35,
#      'askQty': 150,
#      'askPrice': 3832.1,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 45500,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 45500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE45500.00',
#      'openInterest': 2,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 5275,
#      'totalSellQuantity': 5275,
#      'bidQty': 150,
#      'bidprice': 4275.65,
#      'askQty': 300,
#      'askPrice': 4386.8,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 45500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE45500.00',
#      'openInterest': 5827,
#      'changeinOpenInterest': -342,
#      'pchangeinOpenInterest': -5.543848273626195,
#      'totalTradedVolume': 52413,
#      'impliedVolatility': 72.69,
#      'lastPrice': 1.9,
#      'change': -0.6499999999999999,
#      'pChange': -25.49019607843137,
#      'totalBuyQuantity': 169800,
#      'totalSellQuantity': 17125,
#      'bidQty': 1250,
#      'bidprice': 1.9,
#      'askQty': 1475,
#      'askPrice': 1.95,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 46000,
#     'expiryDate': '03-Nov-2022',
#     'CE': {'strikePrice': 46000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE46000.00',
#      'openInterest': 15527,
#      'changeinOpenInterest': 5227,
#      'pchangeinOpenInterest': 50.74757281553398,
#      'totalTradedVolume': 72766,
#      'impliedVolatility': 79.65,
#      'lastPrice': 1.95,
#      'change': -0.5000000000000002,
#      'pChange': -20.408163265306133,
#      'totalBuyQuantity': 211350,
#      'totalSellQuantity': 34725,
#      'bidQty': 3000,
#      'bidprice': 1.9,
#      'askQty': 75,
#      'askPrice': 1.95,
#      'underlyingValue': 41170.15},
#     'PE': {'strikePrice': 46000,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE46000.00',
#      'openInterest': 2,
#      'changeinOpenInterest': 2,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 4,
#      'impliedVolatility': 0,
#      'lastPrice': 4836.85,
#      'change': -438.09999999999945,
#      'pChange': -8.305291993289025,
#      'totalBuyQuantity': 5375,
#      'totalSellQuantity': 5200,
#      'bidQty': 750,
#      'bidprice': 4730.4,
#      'askQty': 300,
#      'askPrice': 4840.25,
#      'underlyingValue': 41170.15}},
#    {'strikePrice': 46500,
#     'expiryDate': '03-Nov-2022',
#     'PE': {'strikePrice': 46500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022PE46500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4050,
#      'totalSellQuantity': 5525,
#      'bidQty': 1475,
#      'bidprice': 5221.65,
#      'askQty': 750,
#      'askPrice': 5378.85,
#      'underlyingValue': 41170.15},
#     'CE': {'strikePrice': 46500,
#      'expiryDate': '03-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY03-11-2022CE46500.00',
#      'openInterest': 57468,
#      'changeinOpenInterest': 9843,
#      'pchangeinOpenInterest': 20.667716535433073,
#      'totalTradedVolume': 101450,
#      'impliedVolatility': 86.26,
#      'lastPrice': 1.85,
#      'change': -0.6499999999999999,
#      'pChange': -25.999999999999996,
#      'totalBuyQuantity': 414950,
#      'totalSellQuantity': 87325,
#      'bidQty': 5225,
#      'bidprice': 1.8,
#      'askQty': 1900,
#      'askPrice': 1.85,
#      'underlyingValue': 41170.15}}],
#   'CE': {'totOI': 1947817, 'totVol': 30978683},
#   'PE': {'totOI': 1324164, 'totVol': 28875322}}}

# %%
df=json_normalize( json_obj["records"])
df
# Out:
#                                          expiryDates  \
# 0  [03-Nov-2022, 10-Nov-2022, 17-Nov-2022, 24-Nov...
#
#                                                 data             timestamp  \
# 0  [{'strikePrice': 25500, 'expiryDate': '29-Dec-...  02-Nov-2022 15:06:55
#
#    underlyingValue                                       strikePrices  \
# 0         41170.15  [25500, 27000, 28500, 29000, 29500, 30000, 305...
#
#           index.key index.index index.indexSymbol  index.last  \
# 0  SECTORAL INDICES  NIFTY BANK        NIFTY BANK     41171.7
#
#    index.variation  ...  index.low  index.previousClose  index.yearHigh  \
# 0          -117.85  ...   41060.45             41289.55        41840.15
#
#    index.yearLow  index.pe  index.pb  index.dy index.declines index.advances  \
# 0       32155.35      17.7      2.72      0.68              8              4
#
#   index.unchanged
# 0               0
#
# [1 rows x 23 columns]

# %%
df_data=json_normalize( json_obj["records"]["data"])
# df_timestamp=json_normalize( json_obj["records"]["timestamp"])
# df_underlyingValue=json_normalize( json_obj["records"]["underlyingValue"])
# df_expiryDates=json_normalize( json_obj["records"]["expiryDates"])
df_strikePrices=json_normalize( json_obj["records"]["strikePrices"])

# %%
df_data
# Out:
#      strikePrice   expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 0          25500  29-Dec-2022         25500.0   29-Dec-2022     BANKNIFTY
# 1          25500  30-Mar-2023             NaN           NaN           NaN
# 2          25500  28-Sep-2023             NaN           NaN           NaN
# 3          25500  29-Jun-2023             NaN           NaN           NaN
# 4          27000  30-Mar-2023             NaN           NaN           NaN
# ..           ...          ...             ...           ...           ...
# 722        49500  29-Dec-2022         49500.0   29-Dec-2022     BANKNIFTY
# 723        49500  25-Jan-2023         49500.0   25-Jan-2023     BANKNIFTY
# 724        49500  30-Mar-2023         49500.0   30-Mar-2023     BANKNIFTY
# 725        49500  29-Jun-2023         49500.0   29-Jun-2023     BANKNIFTY
# 726        49500  28-Sep-2023         49500.0   28-Sep-2023     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 0    OPTIDXBANKNIFTY29-12-2022CE25500.00              0.0
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# ..                                   ...              ...
# 722  OPTIDXBANKNIFTY29-12-2022CE49500.00            655.0
# 723  OPTIDXBANKNIFTY25-01-2023CE49500.00              1.0
# 724  OPTIDXBANKNIFTY30-03-2023CE49500.00              0.0
# 725  OPTIDXBANKNIFTY29-06-2023CE49500.00              0.0
# 726  OPTIDXBANKNIFTY28-09-2023CE49500.00              0.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 0                        0.0                  0.000000                   0.0
# 1                        NaN                       NaN                   NaN
# 2                        NaN                       NaN                   NaN
# 3                        NaN                       NaN                   NaN
# 4                        NaN                       NaN                   NaN
# ..                       ...                       ...                   ...
# 722                     55.0                  9.166667                 201.0
# 723                      0.0                  0.000000                   0.0
# 724                      0.0                  0.000000                   0.0
# 725                      0.0                  0.000000                   0.0
# 726                      0.0                  0.000000                   0.0
#
#      ...  PE.lastPrice  PE.change  PE.pChange  PE.totalBuyQuantity  \
# 0    ...           0.0        0.0         0.0               5100.0
# 1    ...           0.0        0.0         0.0               1000.0
# 2    ...           0.0        0.0         0.0                900.0
# 3    ...           0.0        0.0         0.0                900.0
# 4    ...           0.0        0.0         0.0                975.0
# ..   ...           ...        ...         ...                  ...
# 722  ...           0.0        0.0         0.0               1775.0
# 723  ...           0.0        0.0         0.0                250.0
# 724  ...           NaN        NaN         NaN                  NaN
# 725  ...           NaN        NaN         NaN                  NaN
# 726  ...           NaN        NaN         NaN                  NaN
#
#      PE.totalSellQuantity  PE.bidQty  PE.bidprice  PE.askQty  PE.askPrice  \
# 0                     0.0       25.0         1.10        0.0          0.0
# 1                     0.0      100.0         0.10        0.0          0.0
# 2                     0.0      900.0         0.25        0.0          0.0
# 3                     0.0      900.0         2.20        0.0          0.0
# 4                     0.0       75.0         0.30        0.0          0.0
# ..                    ...        ...          ...        ...          ...
# 722                1800.0      875.0      7663.75       25.0       8094.9
# 723                   0.0      250.0      5862.50        0.0          0.0
# 724                   NaN        NaN          NaN        NaN          NaN
# 725                   NaN        NaN          NaN        NaN          NaN
# 726                   NaN        NaN          NaN        NaN          NaN
#
#      PE.underlyingValue
# 0              41170.15
# 1              41170.15
# 2              41170.15
# 3              41170.15
# 4              41170.15
# ..                  ...
# 722            41170.15
# 723            41170.15
# 724                 NaN
# 725                 NaN
# 726                 NaN
#
# [727 rows x 40 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727 entries, 0 to 726
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   strikePrice               727 non-null    int64
#  1   expiryDate                727 non-null    object
#  2   CE.strikePrice            632 non-null    float64
#  3   CE.expiryDate             632 non-null    object
#  4   CE.underlying             632 non-null    object
#  5   CE.identifier             632 non-null    object
#  6   CE.openInterest           632 non-null    float64
#  7   CE.changeinOpenInterest   632 non-null    float64
#  8   CE.pchangeinOpenInterest  632 non-null    float64
#  9   CE.totalTradedVolume      632 non-null    float64
#  10  CE.impliedVolatility      632 non-null    float64
#  11  CE.lastPrice              632 non-null    float64
#  12  CE.change                 632 non-null    float64
#  13  CE.pChange                632 non-null    float64
#  14  CE.totalBuyQuantity       632 non-null    float64
#  15  CE.totalSellQuantity      632 non-null    float64
#  16  CE.bidQty                 632 non-null    float64
#  17  CE.bidprice               632 non-null    float64
#  18  CE.askQty                 632 non-null    float64
#  19  CE.askPrice               632 non-null    float64
#  20  CE.underlyingValue        632 non-null    float64
#  21  PE.strikePrice            667 non-null    float64
#  22  PE.expiryDate             667 non-null    object
#  23  PE.underlying             667 non-null    object
#  24  PE.identifier             667 non-null    object
#  25  PE.openInterest           667 non-null    float64
#  26  PE.changeinOpenInterest   667 non-null    float64
#  27  PE.pchangeinOpenInterest  667 non-null    float64
#  28  PE.totalTradedVolume      667 non-null    float64
#  29  PE.impliedVolatility      667 non-null    float64
#  30  PE.lastPrice              667 non-null    float64
#  31  PE.change                 667 non-null    float64
#  32  PE.pChange                667 non-null    float64
#  33  PE.totalBuyQuantity       667 non-null    float64
#  34  PE.totalSellQuantity      667 non-null    float64
#  35  PE.bidQty                 667 non-null    float64
#  36  PE.bidprice               667 non-null    float64
#  37  PE.askQty                 667 non-null    float64
#  38  PE.askPrice               667 non-null    float64
#  39  PE.underlyingValue        667 non-null    float64
# dtypes: float64(32), int64(1), object(7)
# memory usage: 227.3+ KB

# %%
for i in df_data.columns:
    if "Date" in i:
        df_data[i]= pd.to_datetime(df_data[i])

# %%
df_data_n=df_data[df_data["expiryDate"]=="2022-11-03"]

# %% [raw]
# df_data_n.to_excel("3Nov22.xlsx")

# %%
df_data_n
# Out:
#      strikePrice expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 22         30500 2022-11-03         30500.0    2022-11-03     BANKNIFTY
# 29         31000 2022-11-03         31000.0    2022-11-03     BANKNIFTY
# 35         31500 2022-11-03         31500.0    2022-11-03     BANKNIFTY
# 41         32000 2022-11-03         32000.0    2022-11-03     BANKNIFTY
# 50         32500 2022-11-03         32500.0    2022-11-03     BANKNIFTY
# ..           ...        ...             ...           ...           ...
# 671        44600 2022-11-03         44600.0    2022-11-03     BANKNIFTY
# 676        45000 2022-11-03         45000.0    2022-11-03     BANKNIFTY
# 689        45500 2022-11-03         45500.0    2022-11-03     BANKNIFTY
# 702        46000 2022-11-03         46000.0    2022-11-03     BANKNIFTY
# 703        46500 2022-11-03         46500.0    2022-11-03     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 22   OPTIDXBANKNIFTY03-11-2022CE30500.00              0.0
# 29   OPTIDXBANKNIFTY03-11-2022CE31000.00              1.0
# 35   OPTIDXBANKNIFTY03-11-2022CE31500.00              0.0
# 41   OPTIDXBANKNIFTY03-11-2022CE32000.00              0.0
# 50   OPTIDXBANKNIFTY03-11-2022CE32500.00              0.0
# ..                                   ...              ...
# 671  OPTIDXBANKNIFTY03-11-2022CE44600.00           1317.0
# 676  OPTIDXBANKNIFTY03-11-2022CE45000.00          28503.0
# 689  OPTIDXBANKNIFTY03-11-2022CE45500.00           5827.0
# 702  OPTIDXBANKNIFTY03-11-2022CE46000.00          15527.0
# 703  OPTIDXBANKNIFTY03-11-2022CE46500.00          57468.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 22                       0.0                  0.000000                   0.0
# 29                       0.0                  0.000000                   0.0
# 35                       0.0                  0.000000                   0.0
# 41                       0.0                  0.000000                   0.0
# 50                       0.0                  0.000000                   0.0
# ..                       ...                       ...                   ...
# 671                   -412.0                -23.828803               24840.0
# 676                    256.0                  0.906291              141364.0
# 689                   -342.0                 -5.543848               52413.0
# 702                   5227.0                 50.747573               72766.0
# 703                   9843.0                 20.667717              101450.0
#
#      ...  PE.lastPrice  PE.change  PE.pChange  PE.totalBuyQuantity  \
# 22   ...          0.85      -0.40  -32.000000             342625.0
# 29   ...          0.85      -0.40  -32.000000             229975.0
# 35   ...          0.80      -0.45  -36.000000              97625.0
# 41   ...          0.85      -0.40  -32.000000             100700.0
# 50   ...          0.90      -0.50  -35.714286             115925.0
# ..   ...           ...        ...         ...                  ...
# 671  ...          0.00       0.00    0.000000               4250.0
# 676  ...          0.00       0.00    0.000000               6450.0
# 689  ...          0.00       0.00    0.000000               5275.0
# 702  ...       4836.85    -438.10   -8.305292               5375.0
# 703  ...          0.00       0.00    0.000000               4050.0
#
#      PE.totalSellQuantity  PE.bidQty  PE.bidprice  PE.askQty  PE.askPrice  \
# 22               175675.0     2175.0         0.80    20175.0         0.85
# 29                33700.0    23000.0         0.80     8800.0         0.85
# 35                22725.0     2225.0         0.80     3600.0         0.85
# 41                21625.0     2100.0         0.80     1025.0         0.85
# 50                 7425.0      575.0         0.90     1125.0         0.95
# ..                    ...        ...          ...        ...          ...
# 671                4050.0      900.0      3309.60      900.0      3484.05
# 676                6600.0     3275.0      3734.35      150.0      3832.10
# 689                5275.0      150.0      4275.65      300.0      4386.80
# 702                5200.0      750.0      4730.40      300.0      4840.25
# 703                5525.0     1475.0      5221.65      750.0      5378.85
#
#      PE.underlyingValue
# 22             41170.15
# 29             41170.15
# 35             41170.15
# 41             41170.15
# 50             41170.15
# ..                  ...
# 671            41170.15
# 676            41170.15
# 689            41170.15
# 702            41170.15
# 703            41170.15
#
# [106 rows x 40 columns]

# %%
df_data_n["Difference"]=df_data_n["CE.underlyingValue"]-df_data_n["CE.strikePrice"]
df_data_n["Ratio"]=df_data_n["CE.openInterest"]/df_data_n["PE.openInterest"]
# Out:
# <ipython-input-11-0ce08887058e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_n["Difference"]=df_data_n["CE.underlyingValue"]-df_data_n["CE.strikePrice"]
# <ipython-input-11-0ce08887058e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_n["Ratio"]=df_data_n["CE.openInterest"]/df_data_n["PE.openInterest"]

# %%
df_call=df_data_n[df_data_n["Difference"]<0].iloc[3:]
df_put=df_data_n[df_data_n["Difference"]>0].iloc[:-3]

# %%
df_call_1=df_call.sort_values(by=["CE.openInterest"],ascending=False).iloc[:13].sort_values(by=['Ratio'],ascending=False)
df_put_1=df_put.sort_values(by=["PE.openInterest"],ascending=False).iloc[:13].sort_values(by=['Ratio'])

# %%
df_put_1
# Out:
#      strikePrice expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 22         30500 2022-11-03         30500.0    2022-11-03     BANKNIFTY
# 311        38500 2022-11-03         38500.0    2022-11-03     BANKNIFTY
# 348        39000 2022-11-03         39000.0    2022-11-03     BANKNIFTY
# 379        39500 2022-11-03         39500.0    2022-11-03     BANKNIFTY
# 272        38000 2022-11-03         38000.0    2022-11-03     BANKNIFTY
# 423        40200 2022-11-03         40200.0    2022-11-03     BANKNIFTY
# 433        40300 2022-11-03         40300.0    2022-11-03     BANKNIFTY
# 414        40000 2022-11-03         40000.0    2022-11-03     BANKNIFTY
# 436        40400 2022-11-03         40400.0    2022-11-03     BANKNIFTY
# 454        40600 2022-11-03         40600.0    2022-11-03     BANKNIFTY
# 456        40700 2022-11-03         40700.0    2022-11-03     BANKNIFTY
# 466        40800 2022-11-03         40800.0    2022-11-03     BANKNIFTY
# 449        40500 2022-11-03         40500.0    2022-11-03     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 22   OPTIDXBANKNIFTY03-11-2022CE30500.00              0.0
# 311  OPTIDXBANKNIFTY03-11-2022CE38500.00            224.0
# 348  OPTIDXBANKNIFTY03-11-2022CE39000.00            902.0
# 379  OPTIDXBANKNIFTY03-11-2022CE39500.00            884.0
# 272  OPTIDXBANKNIFTY03-11-2022CE38000.00            522.0
# 423  OPTIDXBANKNIFTY03-11-2022CE40200.00            809.0
# 433  OPTIDXBANKNIFTY03-11-2022CE40300.00            854.0
# 414  OPTIDXBANKNIFTY03-11-2022CE40000.00           3167.0
# 436  OPTIDXBANKNIFTY03-11-2022CE40400.00           1210.0
# 454  OPTIDXBANKNIFTY03-11-2022CE40600.00           2156.0
# 456  OPTIDXBANKNIFTY03-11-2022CE40700.00           3069.0
# 466  OPTIDXBANKNIFTY03-11-2022CE40800.00           6084.0
# 449  OPTIDXBANKNIFTY03-11-2022CE40500.00          14409.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 22                       0.0                  0.000000                   0.0
# 311                    -11.0                 -4.680851                  16.0
# 348                    -70.0                 -7.201646                 321.0
# 379                   -126.0                -12.475248                 503.0
# 272                    -91.0                -14.845024                 122.0
# 423                   -117.0                -12.634989                1472.0
# 433                    -72.0                 -7.775378                1629.0
# 414                   -303.0                 -8.731988                8570.0
# 436                   -277.0                -18.628110                3315.0
# 454                    -76.0                 -3.405018               17379.0
# 456                   1320.0                 75.471698               31017.0
# 466                   2825.0                 86.683032              116875.0
# 449                   5527.0                 62.226976               54983.0
#
#      ...  PE.pChange  PE.totalBuyQuantity  PE.totalSellQuantity  PE.bidQty  \
# 22   ...  -32.000000             342625.0              175675.0     2175.0
# 311  ...  -33.962264             172200.0               36675.0     5125.0
# 348  ...  -30.379747             241225.0               51950.0    13625.0
# 379  ...  -25.000000             326325.0               78325.0     3125.0
# 272  ...  -23.255814             291175.0               60775.0     1025.0
# 423  ...  -17.256637             245125.0               64175.0     1850.0
# 433  ...  -13.745704             268025.0               75600.0       25.0
# 414  ...  -20.819113             318025.0              199000.0     6275.0
# 436  ...   -9.742896             240275.0               75625.0      425.0
# 454  ...   -1.080632             146725.0               83700.0      475.0
# 456  ...    3.145478             205450.0               94450.0       50.0
# 466  ...    7.157785             203650.0              133400.0       50.0
# 449  ...   -4.444444             227275.0              182250.0     2375.0
#
#      PE.bidprice  PE.askQty  PE.askPrice  PE.underlyingValue  Difference  \
# 22          0.80    20175.0         0.85            41170.15    10670.15
# 311         1.70      275.0         1.75            41170.15     2670.15
# 348         2.70     3200.0         2.75            41170.15     2170.15
# 379         4.60      975.0         4.65            41170.15     1670.15
# 272         1.60     2200.0         1.65            41170.15     3170.15
# 423        18.55      575.0        18.65            41170.15      970.15
# 433        25.05     1075.0        25.10            41170.15      870.15
# 414        11.55     6250.0        11.65            41170.15     1170.15
# 436        33.35       25.0        33.40            41170.15      770.15
# 454        59.45       50.0        59.50            41170.15      570.15
# 456        78.55      925.0        78.80            41170.15      470.15
# 466       102.55      125.0       102.70            41170.15      370.15
# 449        45.00      100.0        45.10            41170.15      670.15
#
#         Ratio
# 22   0.000000
# 311  0.006773
# 348  0.014314
# 379  0.015405
# 272  0.020190
# 423  0.023347
# 433  0.027922
# 414  0.034640
# 436  0.036264
# 454  0.058313
# 456  0.072791
# 466  0.129268
# 449  0.183617
#
# [13 rows x 42 columns]

# %% [raw]
# df_test = pd.read_excel("3Nov22.xlsx",sheet_name=None)
# df_call=df_test["Call"]
# df_put=df_test["Put"]
# df_call_1=df_test["Call 1"]
# df_put_1=df_test["Put 1"]

# %%
def OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy):
    try:
        Max_Profit=round((CE_Sell+PE_Sell-CE_Buy-PE_Buy)*50,2)
        Max_Loss=round((CE_Sell+PE_Sell-CE_Buy-PE_Buy-200)*50,2)
        List=[Max_Profit,Max_Loss,round(-Max_Loss/Max_Profit,2)]
    except Exception as e:
        return [str(e),str(e),str(e)]
    else:
        return List

# %%
def CallPrice(StrikePrice,Data):
    try:
        df=Data[Data["CE.strikePrice"]==StrikePrice]["CE.lastPrice"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

def PutPrice(StrikePrice,Data):
    try:
        df=Data[Data["PE.strikePrice"]==StrikePrice]["PE.lastPrice"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

def CE_OpenInterest(StrikePrice,Data):
    try:
        df=Data[Data["CE.strikePrice"]==StrikePrice]["CE.openInterest"].iloc[0]
    except Exception as e:
        return e
    else:
        return df
    
def PE_OpenInterest(StrikePrice,Data):
    try:
        df=Data[Data["PE.strikePrice"]==StrikePrice]["PE.openInterest"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

# %% [raw]
# my_columns = ["CE StrikePrice", 'PE StrikePrice',"CE StrikePrice 1", 'PE StrikePrice 1','Max Profit', 'Max Loss', "Risk/Reward"]
# final_dataframe = pd.DataFrame(columns = my_columns)
# final_dataframe
#
# for i in df_call_1["CE.strikePrice"]:
#     l=[]
#     l.append(i)
#     for j in df_put_1["PE.strikePrice"]:
#         l.append(j)
#         l.append(l[0]+200)
#         l.append(l[1]-200)
#         CE_Sell=CallPrice(l[0],df_call)
#         PE_Sell=PutPrice(l[1],df_put)
#         CE_Buy=CallPrice(l[2],df_call)
#         PE_Buy=PutPrice(l[3],df_put)
#         l=l+OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy)
#         final_dataframe = final_dataframe.append(
#                                         pd.Series(l,index = my_columns),
#                                         ignore_index = True)
#         l=[i]

# %%
my_columns = ["CE StrikePrice", "CE OpenInterest",'PE StrikePrice',"PE OpenInterest","CE StrikePrice 1","CE OpenInterest 1", 'PE StrikePrice 1',"PE OpenInterest 1",'Max Profit', 'Max Loss', "Risk/Reward"]
final_dataframe = pd.DataFrame(columns = my_columns)


for i in df_call_1["CE.strikePrice"]:
    l=[]
    l.append(i)
    l.append(CE_OpenInterest(i,df_data_n))
    for j in df_put_1["PE.strikePrice"]:
        l.append(j)
        l.append(PE_OpenInterest(j,df_data_n))
        
        l.append(l[0]+200)
        l.append(CE_OpenInterest(l[0]+200,df_data_n))
        
        l.append(l[2]-200)
        l.append(PE_OpenInterest(l[2]-200,df_data_n))
        
        CE_Sell=CallPrice(l[0],df_data_n)
        PE_Sell=PutPrice(l[2],df_data_n)
        CE_Buy=CallPrice(l[4],df_data_n)
        PE_Buy=PutPrice(l[6],df_data_n)
        l=l+OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy)
        final_dataframe = final_dataframe.append(
                                        pd.Series(l,index = my_columns), 
                                        ignore_index = True)
        l=[i,CE_OpenInterest(i,df_data_n)]
# Out:
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-25-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(

# %%
final_dataframe['Risk/Reward'] = pd.to_numeric(final_dataframe['Risk/Reward'], errors="coerce")
final_dataframe.dropna(how="any", inplace=True)

# %%
df=final_dataframe[final_dataframe["Risk/Reward"]<=3][final_dataframe["Risk/Reward"]>0]
# Out:
# <ipython-input-27-496275cc996c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df=final_dataframe[final_dataframe["Risk/Reward"]<=3][final_dataframe["Risk/Reward"]>0]

# %%
df.sort_values(by=["Risk/Reward"])
# Out:
#     CE StrikePrice CE OpenInterest PE StrikePrice PE OpenInterest  \
# 167        41500.0        188524.0        40800.0         47065.0
# 166        41500.0        188524.0        40700.0         42162.0
# 154        41600.0         80042.0        40800.0         47065.0
# 165        41500.0        188524.0        40600.0         36973.0
# 153        41600.0         80042.0        40700.0         42162.0
# 128        41700.0         84393.0        40800.0         47065.0
# 168        41500.0        188524.0        40500.0         78473.0
# 152        41600.0         80042.0        40600.0         36973.0
# 164        41500.0        188524.0        40400.0         33366.0
# 141        41800.0         85558.0        40800.0         47065.0
# 127        41700.0         84393.0        40700.0         42162.0
# 162        41500.0        188524.0        40300.0         30585.0
# 155        41600.0         80042.0        40500.0         78473.0
# 161        41500.0        188524.0        40200.0         34651.0
# 115        41900.0         55938.0        40800.0         47065.0
# 126        41700.0         84393.0        40600.0         36973.0
# 151        41600.0         80042.0        40400.0         33366.0
# 140        41800.0         85558.0        40700.0         42162.0
# 163        41500.0        188524.0        40000.0         91425.0
# 159        41500.0        188524.0        39500.0         57385.0
# 149        41600.0         80042.0        40300.0         30585.0
# 158        41500.0        188524.0        39000.0         63014.0
# 160        41500.0        188524.0        38000.0         25854.0
# 102        42000.0        132142.0        40800.0         47065.0
# 157        41500.0        188524.0        38500.0         33074.0
# 129        41700.0         84393.0        40500.0         78473.0
# 148        41600.0         80042.0        40200.0         34651.0
# 139        41800.0         85558.0        40600.0         36973.0
# 114        41900.0         55938.0        40700.0         42162.0
# 89         42100.0         52492.0        40800.0         47065.0
# 125        41700.0         84393.0        40400.0         33366.0
# 150        41600.0         80042.0        40000.0         91425.0
#
#     CE StrikePrice 1 CE OpenInterest 1 PE StrikePrice 1 PE OpenInterest 1  \
# 167          41700.0           84393.0          40600.0           36973.0
# 166          41700.0           84393.0          40500.0           78473.0
# 154          41800.0           85558.0          40600.0           36973.0
# 165          41700.0           84393.0          40400.0           33366.0
# 153          41800.0           85558.0          40500.0           78473.0
# 128          41900.0           55938.0          40600.0           36973.0
# 168          41700.0           84393.0          40300.0           30585.0
# 152          41800.0           85558.0          40400.0           33366.0
# 164          41700.0           84393.0          40200.0           34651.0
# 141          42000.0          132142.0          40600.0           36973.0
# 127          41900.0           55938.0          40500.0           78473.0
# 162          41700.0           84393.0          40100.0           18270.0
# 155          41800.0           85558.0          40300.0           30585.0
# 161          41700.0           84393.0          40000.0           91425.0
# 115          42100.0           52492.0          40600.0           36973.0
# 126          41900.0           55938.0          40400.0           33366.0
# 151          41800.0           85558.0          40200.0           34651.0
# 140          42000.0          132142.0          40500.0           78473.0
# 163          41700.0           84393.0          39800.0           22742.0
# 159          41700.0           84393.0          39300.0           12306.0
# 149          41800.0           85558.0          40100.0           18270.0
# 158          41700.0           84393.0          38800.0            5410.0
# 160          41700.0           84393.0          37800.0            4048.0
# 102          42200.0           48813.0          40600.0           36973.0
# 157          41700.0           84393.0          38300.0            6393.0
# 129          41900.0           55938.0          40300.0           30585.0
# 148          41800.0           85558.0          40000.0           91425.0
# 139          42000.0          132142.0          40400.0           33366.0
# 114          42100.0           52492.0          40500.0           78473.0
# 89           42300.0           58330.0          40600.0           36973.0
# 125          41900.0           55938.0          40200.0           34651.0
# 150          41800.0           85558.0          39800.0           22742.0
#
#     Max Profit Max Loss  Risk/Reward
# 167     4957.5  -5042.5         1.02
# 166     4482.5  -5517.5         1.23
# 154     4462.5  -5537.5         1.24
# 165     4112.5  -5887.5         1.43
# 153     3987.5  -6012.5         1.51
# 128     3970.0  -6030.0         1.52
# 168     3807.5  -6192.5         1.63
# 152     3617.5  -6382.5         1.76
# 164     3537.5  -6462.5         1.83
# 141     3510.0  -6490.0         1.85
# 127     3495.0  -6505.0         1.86
# 162     3335.0  -6665.0         2.00
# 155     3312.5  -6687.5         2.02
# 161     3160.0  -6840.0         2.16
# 115     3142.5  -6857.5         2.18
# 126     3125.0  -6875.0         2.20
# 151     3042.5  -6957.5         2.29
# 140     3035.0  -6965.0         2.29
# 163     3007.5  -6992.5         2.33
# 159     2865.0  -7135.0         2.49
# 149     2840.0  -7160.0         2.52
# 158     2832.5  -7167.5         2.53
# 160     2827.5  -7172.5         2.54
# 102     2822.5  -7177.5         2.54
# 157     2817.5  -7182.5         2.55
# 129     2820.0  -7180.0         2.55
# 148     2665.0  -7335.0         2.75
# 139     2665.0  -7335.0         2.75
# 114     2667.5  -7332.5         2.75
# 89      2567.5  -7432.5         2.89
# 125     2550.0  -7450.0         2.92
# 150     2512.5  -7487.5         2.98

# %%
df["%diff"]=  (df["CE StrikePrice"]/df["PE StrikePrice"]-1)*100

# %%
df
# Out:
#     CE StrikePrice PE StrikePrice CE StrikePrice 1 PE StrikePrice 1  \
# 89         42100.0        40800.0          42300.0          40600.0
# 102        42000.0        40800.0          42200.0          40600.0
# 114        41900.0        40700.0          42100.0          40500.0
# 115        41900.0        40800.0          42100.0          40600.0
# 125        41700.0        40400.0          41900.0          40200.0
# 126        41700.0        40600.0          41900.0          40400.0
# 127        41700.0        40700.0          41900.0          40500.0
# 128        41700.0        40800.0          41900.0          40600.0
# 129        41700.0        40500.0          41900.0          40300.0
# 139        41800.0        40600.0          42000.0          40400.0
# 140        41800.0        40700.0          42000.0          40500.0
# 141        41800.0        40800.0          42000.0          40600.0
# 148        41600.0        40200.0          41800.0          40000.0
# 149        41600.0        40300.0          41800.0          40100.0
# 150        41600.0        40000.0          41800.0          39800.0
# 151        41600.0        40400.0          41800.0          40200.0
# 152        41600.0        40600.0          41800.0          40400.0
# 153        41600.0        40700.0          41800.0          40500.0
# 154        41600.0        40800.0          41800.0          40600.0
# 155        41600.0        40500.0          41800.0          40300.0
# 157        41500.0        38500.0          41700.0          38300.0
# 158        41500.0        39000.0          41700.0          38800.0
# 159        41500.0        39500.0          41700.0          39300.0
# 160        41500.0        38000.0          41700.0          37800.0
# 161        41500.0        40200.0          41700.0          40000.0
# 162        41500.0        40300.0          41700.0          40100.0
# 163        41500.0        40000.0          41700.0          39800.0
# 164        41500.0        40400.0          41700.0          40200.0
# 165        41500.0        40600.0          41700.0          40400.0
# 166        41500.0        40700.0          41700.0          40500.0
# 167        41500.0        40800.0          41700.0          40600.0
# 168        41500.0        40500.0          41700.0          40300.0
#
#     Max Profit Max Loss  Risk/Reward     %diff
# 89      2567.5  -7432.5         2.89  3.186275
# 102     2822.5  -7177.5         2.54  2.941176
# 114     2667.5  -7332.5         2.75  2.948403
# 115     3142.5  -6857.5         2.18  2.696078
# 125     2550.0  -7450.0         2.92  3.217822
# 126     3125.0  -6875.0         2.20   2.70936
# 127     3495.0  -6505.0         1.86  2.457002
# 128     3970.0  -6030.0         1.52  2.205882
# 129     2820.0  -7180.0         2.55  2.962963
# 139     2665.0  -7335.0         2.75  2.955665
# 140     3035.0  -6965.0         2.29  2.702703
# 141     3510.0  -6490.0         1.85   2.45098
# 148     2665.0  -7335.0         2.75  3.482587
# 149     2840.0  -7160.0         2.52  3.225806
# 150     2512.5  -7487.5         2.98       4.0
# 151     3042.5  -6957.5         2.29  2.970297
# 152     3617.5  -6382.5         1.76  2.463054
# 153     3987.5  -6012.5         1.51  2.211302
# 154     4462.5  -5537.5         1.24  1.960784
# 155     3312.5  -6687.5         2.02  2.716049
# 157     2817.5  -7182.5         2.55  7.792208
# 158     2832.5  -7167.5         2.53  6.410256
# 159     2865.0  -7135.0         2.49  5.063291
# 160     2827.5  -7172.5         2.54  9.210526
# 161     3160.0  -6840.0         2.16  3.233831
# 162     3335.0  -6665.0         2.00  2.977667
# 163     3007.5  -6992.5         2.33      3.75
# 164     3537.5  -6462.5         1.83  2.722772
# 165     4112.5  -5887.5         1.43  2.216749
# 166     4482.5  -5517.5         1.23  1.965602
# 167     4957.5  -5042.5         1.02  1.715686
# 168     3807.5  -6192.5         1.63  2.469136
