# %%
import numpy as np #The Numpy numerical computing library
import pandas as pd #The Pandas data science library
import requests #The requests library for HTTP requests in Python
import xlsxwriter #The XlsxWriter libarary for 
import math #The Python math module
import pandas as pd
import json
from pandas import json_normalize

# %% [raw]
# df=pd.read_csv("option-chain-ED-NIFTY-27-Oct-2022.csv")

# %% [raw]
# df

# %%
import requests
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36','Accept-Encoding': 'gzip, deflate, br','Accept-Language': 'en-US,en;q=0.9,hi;q=0.8'}
url = "https://www.nseindia.com/api/option-chain-indices?symbol=BANKNIFTY"
json_obj = requests.get(url, headers = headers).json()

# %%
json_obj
# Out:
# {'records': {'expiryDates': ['10-Nov-2022',
#    '17-Nov-2022',
#    '24-Nov-2022',
#    '01-Dec-2022',
#    '08-Dec-2022',
#    '29-Dec-2022',
#    '25-Jan-2023',
#    '30-Mar-2023',
#    '29-Jun-2023',
#    '28-Sep-2023'],
#   'data': [{'strikePrice': 25500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 25500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 15520.9,
#      'askQty': 875,
#      'askPrice': 16988.4,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 16600,
#      'totalSellQuantity': 0,
#      'bidQty': 5400,
#      'bidprice': 1.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 25500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1000,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 25500,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1000,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 25500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 25500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE25500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 27000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 27000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 27000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE27000.00',
#      'openInterest': 109,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 4.65,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6600,
#      'totalSellQuantity': 0,
#      'bidQty': 3800,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 27000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 14091.35,
#      'askQty': 875,
#      'askPrice': 15498.35,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 27000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 27000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE27000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 28500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 28500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE28500.00',
#      'openInterest': 64,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 30.7,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 5175,
#      'totalSellQuantity': 0,
#      'bidQty': 2300,
#      'bidprice': 3.2,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 28500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1100,
#      'totalSellQuantity': 875,
#      'bidQty': 225,
#      'bidprice': 12650.8,
#      'askQty': 875,
#      'askPrice': 14210.7,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 28500,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE28500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 0.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 28500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 28500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE28500.00',
#      'openInterest': 3,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 500,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 975,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 29000,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 29000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE29000.00',
#      'openInterest': 13,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4725,
#      'totalSellQuantity': 0,
#      'bidQty': 2000,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 29000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE29000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2275,
#      'totalSellQuantity': 1375,
#      'bidQty': 500,
#      'bidprice': 12316.05,
#      'askQty': 500,
#      'askPrice': 13107.55,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 29500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 29500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE29500.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 9700,
#      'change': 358.2999999999993,
#      'pChange': 3.835490328312826,
#      'totalBuyQuantity': 2275,
#      'totalSellQuantity': 1375,
#      'bidQty': 500,
#      'bidprice': 11896.7,
#      'askQty': 500,
#      'askPrice': 12607.95,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 29500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE29500.00',
#      'openInterest': 24,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 25.75,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 7725,
#      'totalSellQuantity': 0,
#      'bidQty': 1825,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3725,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 30000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 10595.8,
#      'askQty': 875,
#      'askPrice': 12830,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE30000.00',
#      'openInterest': 184,
#      'changeinOpenInterest': -10,
#      'pchangeinOpenInterest': -5.154639175257732,
#      'totalTradedVolume': 41,
#      'impliedVolatility': 55.78,
#      'lastPrice': 3.55,
#      'change': -0.9000000000000004,
#      'pChange': -20.224719101123604,
#      'totalBuyQuantity': 3525,
#      'totalSellQuantity': 3150,
#      'bidQty': 625,
#      'bidprice': 3.6,
#      'askQty': 350,
#      'askPrice': 4.5,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 30000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE30000.00',
#      'openInterest': 106,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 11250,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2400,
#      'totalSellQuantity': 1575,
#      'bidQty': 125,
#      'bidprice': 11635.7,
#      'askQty': 125,
#      'askPrice': 11942,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE30000.00',
#      'openInterest': 1412,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 4.9,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 19100,
#      'totalSellQuantity': 0,
#      'bidQty': 14200,
#      'bidprice': 4.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 30000,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE30000.00',
#      'openInterest': 14,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 11350,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 1075,
#      'bidQty': 875,
#      'bidprice': 10215.05,
#      'askQty': 875,
#      'askPrice': 12879.95,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 25,
#      'bidQty': 900,
#      'bidprice': 0.7,
#      'askQty': 25,
#      'askPrice': 499,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30000,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 30000,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE30000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 25,
#      'bidQty': 50,
#      'bidprice': 0.3,
#      'askQty': 25,
#      'askPrice': 199,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30500,
#     'expiryDate': '01-Dec-2022',
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 10139.8,
#      'askQty': 875,
#      'askPrice': 12284,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30500,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3900,
#      'totalSellQuantity': 2275,
#      'bidQty': 750,
#      'bidprice': 10931.85,
#      'askQty': 900,
#      'askPrice': 11378.35,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE30500.00',
#      'openInterest': 41273,
#      'changeinOpenInterest': 12177,
#      'pchangeinOpenInterest': 41.85111355512785,
#      'totalTradedVolume': 263257,
#      'impliedVolatility': 114.32,
#      'lastPrice': 1.3,
#      'change': -0.34999999999999987,
#      'pChange': -21.212121212121204,
#      'totalBuyQuantity': 511075,
#      'totalSellQuantity': 289575,
#      'bidQty': 31075,
#      'bidprice': 1.25,
#      'askQty': 45450,
#      'askPrice': 1.3,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30500,
#     'expiryDate': '17-Nov-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE30500.00',
#      'openInterest': 67,
#      'changeinOpenInterest': 16,
#      'pchangeinOpenInterest': 31.372549019607842,
#      'totalTradedVolume': 78,
#      'impliedVolatility': 68.02,
#      'lastPrice': 3.05,
#      'change': 0.04999999999999982,
#      'pChange': 1.6666666666666607,
#      'totalBuyQuantity': 15050,
#      'totalSellQuantity': 7400,
#      'bidQty': 1275,
#      'bidprice': 3.05,
#      'askQty': 400,
#      'askPrice': 4.45,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 2125,
#      'bidQty': 750,
#      'bidprice': 10787.55,
#      'askQty': 750,
#      'askPrice': 12386.4,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 30500,
#     'expiryDate': '24-Nov-2022',
#     'PE': {'strikePrice': 30500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE30500.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 25,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4500,
#      'totalSellQuantity': 0,
#      'bidQty': 1800,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 30500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE30500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1950,
#      'totalSellQuantity': 1375,
#      'bidQty': 575,
#      'bidprice': 10787.25,
#      'askQty': 500,
#      'askPrice': 12042.3,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31000,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3900,
#      'totalSellQuantity': 2275,
#      'bidQty': 750,
#      'bidprice': 10597.05,
#      'askQty': 900,
#      'askPrice': 10864.35,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE31000.00',
#      'openInterest': 8144,
#      'changeinOpenInterest': -858,
#      'pchangeinOpenInterest': -9.531215285492113,
#      'totalTradedVolume': 79622,
#      'impliedVolatility': 109.15,
#      'lastPrice': 1.35,
#      'change': -0.2999999999999998,
#      'pChange': -18.181818181818173,
#      'totalBuyQuantity': 179475,
#      'totalSellQuantity': 88750,
#      'bidQty': 50525,
#      'bidprice': 1.25,
#      'askQty': 7525,
#      'askPrice': 1.35,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31000,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE31000.00',
#      'openInterest': 53,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 10370,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2475,
#      'totalSellQuantity': 1375,
#      'bidQty': 500,
#      'bidprice': 10370.5,
#      'askQty': 500,
#      'askPrice': 11023.7,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE31000.00',
#      'openInterest': 155,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4475,
#      'totalSellQuantity': 0,
#      'bidQty': 1800,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31000,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1925,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9683.8,
#      'askQty': 875,
#      'askPrice': 11746.75,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31000,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 31000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE31000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 2125,
#      'bidQty': 750,
#      'bidprice': 10299.3,
#      'askQty': 750,
#      'askPrice': 11031.55,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE31000.00',
#      'openInterest': 62,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 9675,
#      'totalSellQuantity': 750,
#      'bidQty': 75,
#      'bidprice': 3,
#      'askQty': 375,
#      'askPrice': 4.1,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '08-Dec-2022',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '08-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY08-12-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1325,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '29-Dec-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9587.55,
#      'askQty': 875,
#      'askPrice': 11020.65,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE31500.00',
#      'openInterest': 278,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 19.95,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2850,
#      'totalSellQuantity': 0,
#      'bidQty': 400,
#      'bidprice': 12,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '25-Jan-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE31500.00',
#      'openInterest': 25,
#      'changeinOpenInterest': 3,
#      'pchangeinOpenInterest': 13.636363636363637,
#      'totalTradedVolume': 3,
#      'impliedVolatility': 31.76,
#      'lastPrice': 40,
#      'change': -0.45000000000000284,
#      'pChange': -1.1124845488257178,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 550,
#      'bidQty': 275,
#      'bidprice': 25,
#      'askQty': 50,
#      'askPrice': 40,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 8798.6,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '30-Mar-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '30-Mar-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY30-03-2023PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 925,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.7,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '29-Jun-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '29-Jun-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-06-2023PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '28-Sep-2023',
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '28-Sep-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY28-09-2023PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 950,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 2.25,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3900,
#      'totalSellQuantity': 3150,
#      'bidQty': 750,
#      'bidprice': 10140.35,
#      'askQty': 900,
#      'askPrice': 10363.95,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE31500.00',
#      'openInterest': 3356,
#      'changeinOpenInterest': 1317,
#      'pchangeinOpenInterest': 64.5904855321236,
#      'totalTradedVolume': 16958,
#      'impliedVolatility': 105.25,
#      'lastPrice': 1.6,
#      'change': -0.09999999999999987,
#      'pChange': -5.882352941176463,
#      'totalBuyQuantity': 50650,
#      'totalSellQuantity': 3950,
#      'bidQty': 1100,
#      'bidprice': 1.4,
#      'askQty': 1800,
#      'askPrice': 1.6,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 1375,
#      'bidQty': 750,
#      'bidprice': 9809.6,
#      'askQty': 500,
#      'askPrice': 10551.45,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 8250,
#      'totalSellQuantity': 0,
#      'bidQty': 500,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE31500.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 9850,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2475,
#      'totalSellQuantity': 1375,
#      'bidQty': 500,
#      'bidprice': 9822,
#      'askQty': 500,
#      'askPrice': 10662.6,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE31500.00',
#      'openInterest': 12,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 22100,
#      'totalSellQuantity': 0,
#      'bidQty': 1950,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 31500,
#     'expiryDate': '01-Dec-2022',
#     'CE': {'strikePrice': 31500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 9336.55,
#      'askQty': 875,
#      'askPrice': 11204.5,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 31500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE31500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '08-Dec-2022',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '08-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY08-12-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.15,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '17-Nov-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 1375,
#      'bidQty': 750,
#      'bidprice': 9321,
#      'askQty': 500,
#      'askPrice': 10167.5,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6175,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE32000.00',
#      'openInterest': 1246,
#      'changeinOpenInterest': 144,
#      'pchangeinOpenInterest': 13.067150635208712,
#      'totalTradedVolume': 24897,
#      'impliedVolatility': 97.99,
#      'lastPrice': 1.3,
#      'change': -0.44999999999999996,
#      'pChange': -25.71428571428571,
#      'totalBuyQuantity': 88075,
#      'totalSellQuantity': 20350,
#      'bidQty': 10400,
#      'bidprice': 1.3,
#      'askQty': 225,
#      'askPrice': 1.4,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3900,
#      'totalSellQuantity': 3150,
#      'bidQty': 750,
#      'bidprice': 9640.9,
#      'askQty': 900,
#      'askPrice': 9860.7,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE32000.00',
#      'openInterest': 28,
#      'changeinOpenInterest': 2,
#      'pchangeinOpenInterest': 7.6923076923076925,
#      'totalTradedVolume': 2,
#      'impliedVolatility': 0,
#      'lastPrice': 9700,
#      'change': 396.39999999999964,
#      'pChange': 4.26071628186938,
#      'totalBuyQuantity': 1975,
#      'totalSellQuantity': 1375,
#      'bidQty': 575,
#      'bidprice': 9332.95,
#      'askQty': 500,
#      'askPrice': 10039.5,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE32000.00',
#      'openInterest': 1118,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 12,
#      'impliedVolatility': 45.13,
#      'lastPrice': 3.05,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 16100,
#      'totalSellQuantity': 0,
#      'bidQty': 2000,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '01-Dec-2022',
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 8880.55,
#      'askQty': 875,
#      'askPrice': 10646,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32000,
#     'expiryDate': '25-Jan-2023',
#     'PE': {'strikePrice': 32000,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE32000.00',
#      'openInterest': 5,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 42.4,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1800,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 20.6,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 32000,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE32000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 8298.6,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '01-Dec-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1250,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 1.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '01-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY01-12-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 875,
#      'totalSellQuantity': 875,
#      'bidQty': 875,
#      'bidprice': 8423.1,
#      'askQty': 875,
#      'askPrice': 10100,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '29-Dec-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022PE32500.00',
#      'openInterest': 64,
#      'changeinOpenInterest': -10,
#      'pchangeinOpenInterest': -13.513513513513514,
#      'totalTradedVolume': 23,
#      'impliedVolatility': 33.11,
#      'lastPrice': 29,
#      'change': 0.05000000000000071,
#      'pChange': 0.1727115716753047,
#      'totalBuyQuantity': 4275,
#      'totalSellQuantity': 250,
#      'bidQty': 100,
#      'bidprice': 13.05,
#      'askQty': 225,
#      'askPrice': 28,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '29-Dec-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY29-12-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 1375,
#      'bidQty': 875,
#      'bidprice': 8655,
#      'askQty': 500,
#      'askPrice': 9939.1,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '25-Jan-2023',
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 7803.75,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '25-Jan-2023',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY25-01-2023PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 900,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 5.15,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '24-Nov-2022',
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 1775,
#      'totalSellQuantity': 1375,
#      'bidQty': 400,
#      'bidprice': 8828.05,
#      'askQty': 500,
#      'askPrice': 9863.15,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '24-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY24-11-2022PE32500.00',
#      'openInterest': 26,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 19,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 17650,
#      'totalSellQuantity': 0,
#      'bidQty': 2350,
#      'bidprice': 3.1,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '17-Nov-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022PE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 6175,
#      'totalSellQuantity': 0,
#      'bidQty': 900,
#      'bidprice': 3.05,
#      'askQty': 0,
#      'askPrice': 0,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 32500,
#      'expiryDate': '17-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY17-11-2022CE32500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 2125,
#      'totalSellQuantity': 1375,
#      'bidQty': 750,
#      'bidprice': 8843.35,
#      'askQty': 500,
#      'askPrice': 9621.65,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 32500,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 32500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
# ...
#      'change': -434,
#      'pChange': -29.379907933929054,
#      'totalBuyQuantity': 49400,
#      'totalSellQuantity': 5275,
#      'bidQty': 200,
#      'bidprice': 1023.1,
#      'askQty': 50,
#      'askPrice': 1055.9,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 42800,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE42800.00',
#      'openInterest': 22927,
#      'changeinOpenInterest': 2320,
#      'pchangeinOpenInterest': 11.258310282913573,
#      'totalTradedVolume': 477577,
#      'impliedVolatility': 15.9,
#      'lastPrice': 9.35,
#      'change': -7.950000000000001,
#      'pChange': -45.95375722543353,
#      'totalBuyQuantity': 89775,
#      'totalSellQuantity': 30975,
#      'bidQty': 75,
#      'bidprice': 8.3,
#      'askQty': 175,
#      'askPrice': 9.35,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 42900,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 42900,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE42900.00',
#      'openInterest': 101,
#      'changeinOpenInterest': 1,
#      'pchangeinOpenInterest': 1,
#      'totalTradedVolume': 92,
#      'impliedVolatility': 0,
#      'lastPrice': 1134.5,
#      'change': -433.95000000000005,
#      'pChange': -27.66744237941917,
#      'totalBuyQuantity': 52800,
#      'totalSellQuantity': 5850,
#      'bidQty': 300,
#      'bidprice': 1132.3,
#      'askQty': 200,
#      'askPrice': 1167.05,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 42900,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE42900.00',
#      'openInterest': 14998,
#      'changeinOpenInterest': 4930,
#      'pchangeinOpenInterest': 48.96702423520063,
#      'totalTradedVolume': 342113,
#      'impliedVolatility': 16.22,
#      'lastPrice': 6.95,
#      'change': -7.55,
#      'pChange': -52.06896551724138,
#      'totalBuyQuantity': 96825,
#      'totalSellQuantity': 47275,
#      'bidQty': 100,
#      'bidprice': 6.45,
#      'askQty': 50,
#      'askPrice': 6.95,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 43000,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 43000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE43000.00',
#      'openInterest': 867,
#      'changeinOpenInterest': 303,
#      'pchangeinOpenInterest': 53.723404255319146,
#      'totalTradedVolume': 7921,
#      'impliedVolatility': 0,
#      'lastPrice': 1249.4,
#      'change': -457.5,
#      'pChange': -26.802976155603726,
#      'totalBuyQuantity': 55600,
#      'totalSellQuantity': 10900,
#      'bidQty': 125,
#      'bidprice': 1242.9,
#      'askQty': 225,
#      'askPrice': 1250.7,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 43000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE43000.00',
#      'openInterest': 81767,
#      'changeinOpenInterest': 4840,
#      'pchangeinOpenInterest': 6.2916791243646575,
#      'totalTradedVolume': 828315,
#      'impliedVolatility': 16.59,
#      'lastPrice': 5.3,
#      'change': -7.3500000000000005,
#      'pChange': -58.10276679841897,
#      'totalBuyQuantity': 88675,
#      'totalSellQuantity': 132100,
#      'bidQty': 6575,
#      'bidprice': 5.3,
#      'askQty': 1550,
#      'askPrice': 5.35,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 43100,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 43100,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE43100.00',
#      'openInterest': 11910,
#      'changeinOpenInterest': 208,
#      'pchangeinOpenInterest': 1.7774739360793026,
#      'totalTradedVolume': 219296,
#      'impliedVolatility': 17.08,
#      'lastPrice': 4.25,
#      'change': -6.199999999999999,
#      'pChange': -59.33014354066985,
#      'totalBuyQuantity': 61625,
#      'totalSellQuantity': 15450,
#      'bidQty': 425,
#      'bidprice': 4.25,
#      'askQty': 25,
#      'askPrice': 4.45,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 43100,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE43100.00',
#      'openInterest': 54,
#      'changeinOpenInterest': 4,
#      'pchangeinOpenInterest': 8,
#      'totalTradedVolume': 10,
#      'impliedVolatility': 21.57,
#      'lastPrice': 1394.45,
#      'change': -373.45000000000005,
#      'pChange': -21.12393234911477,
#      'totalBuyQuantity': 11675,
#      'totalSellQuantity': 4475,
#      'bidQty': 150,
#      'bidprice': 1333.8,
#      'askQty': 75,
#      'askPrice': 1361.3,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 43200,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 43200,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE43200.00',
#      'openInterest': 12326,
#      'changeinOpenInterest': 724,
#      'pchangeinOpenInterest': 6.240303395966213,
#      'totalTradedVolume': 175743,
#      'impliedVolatility': 17.66,
#      'lastPrice': 3.55,
#      'change': -5.3500000000000005,
#      'pChange': -60.1123595505618,
#      'totalBuyQuantity': 74950,
#      'totalSellQuantity': 19750,
#      'bidQty': 600,
#      'bidprice': 3.6,
#      'askQty': 150,
#      'askPrice': 3.9,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 43200,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE43200.00',
#      'openInterest': 18,
#      'changeinOpenInterest': 8,
#      'pchangeinOpenInterest': 80,
#      'totalTradedVolume': 22,
#      'impliedVolatility': 0,
#      'lastPrice': 1429.25,
#      'change': -420.75,
#      'pChange': -22.743243243243246,
#      'totalBuyQuantity': 13450,
#      'totalSellQuantity': 5500,
#      'bidQty': 2825,
#      'bidprice': 1370.65,
#      'askQty': 50,
#      'askPrice': 1481.05,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 43300,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 43300,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE43300.00',
#      'openInterest': 12417,
#      'changeinOpenInterest': -378,
#      'pchangeinOpenInterest': -2.954279015240328,
#      'totalTradedVolume': 134177,
#      'impliedVolatility': 18.2,
#      'lastPrice': 2.95,
#      'change': -4.75,
#      'pChange': -61.68831168831169,
#      'totalBuyQuantity': 68750,
#      'totalSellQuantity': 14125,
#      'bidQty': 325,
#      'bidprice': 2.95,
#      'askQty': 500,
#      'askPrice': 3.2,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 43300,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE43300.00',
#      'openInterest': 4,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 1,
#      'impliedVolatility': 46.6,
#      'lastPrice': 1764.8,
#      'change': -226.04999999999995,
#      'pChange': -11.354446593163722,
#      'totalBuyQuantity': 9750,
#      'totalSellQuantity': 5525,
#      'bidQty': 100,
#      'bidprice': 1455.65,
#      'askQty': 125,
#      'askPrice': 1554,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 43500,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 43500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE43500.00',
#      'openInterest': 68835,
#      'changeinOpenInterest': -23239,
#      'pchangeinOpenInterest': -25.239481286791058,
#      'totalTradedVolume': 517738,
#      'impliedVolatility': 20.18,
#      'lastPrice': 3,
#      'change': -3.95,
#      'pChange': -56.83453237410072,
#      'totalBuyQuantity': 194550,
#      'totalSellQuantity': 61475,
#      'bidQty': 2800,
#      'bidprice': 3,
#      'askQty': 50,
#      'askPrice': 3.05,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 43500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE43500.00',
#      'openInterest': 52,
#      'changeinOpenInterest': 29,
#      'pchangeinOpenInterest': 126.08695652173913,
#      'totalTradedVolume': 489,
#      'impliedVolatility': 0,
#      'lastPrice': 1741.05,
#      'change': -446.85000000000014,
#      'pChange': -20.423693953105722,
#      'totalBuyQuantity': 34600,
#      'totalSellQuantity': 5025,
#      'bidQty': 100,
#      'bidprice': 1738.8,
#      'askQty': 125,
#      'askPrice': 1749.2,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 44000,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 44000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE44000.00',
#      'openInterest': 51,
#      'changeinOpenInterest': 4,
#      'pchangeinOpenInterest': 8.51063829787234,
#      'totalTradedVolume': 13,
#      'impliedVolatility': 0,
#      'lastPrice': 2225,
#      'change': -562.4000000000001,
#      'pChange': -20.176508574298634,
#      'totalBuyQuantity': 27575,
#      'totalSellQuantity': 6500,
#      'bidQty': 2425,
#      'bidprice': 2191.85,
#      'askQty': 750,
#      'askPrice': 2293.5,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 44000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE44000.00',
#      'openInterest': 53201,
#      'changeinOpenInterest': 11692,
#      'pchangeinOpenInterest': 28.167385386301767,
#      'totalTradedVolume': 384758,
#      'impliedVolatility': 24.29,
#      'lastPrice': 2.45,
#      'change': -2.25,
#      'pChange': -47.87234042553191,
#      'totalBuyQuantity': 125475,
#      'totalSellQuantity': 113325,
#      'bidQty': 8550,
#      'bidprice': 2.45,
#      'askQty': 8975,
#      'askPrice': 2.6,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 44500,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 44500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE44500.00',
#      'openInterest': 48,
#      'changeinOpenInterest': 48,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 48,
#      'impliedVolatility': 46.82,
#      'lastPrice': 2828,
#      'change': -488.9499999999998,
#      'pChange': -14.740951777988812,
#      'totalBuyQuantity': 4775,
#      'totalSellQuantity': 6000,
#      'bidQty': 2100,
#      'bidprice': 2673.3,
#      'askQty': 750,
#      'askPrice': 2812.9,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 44500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE44500.00',
#      'openInterest': 37441,
#      'changeinOpenInterest': -18937,
#      'pchangeinOpenInterest': -33.58934336088545,
#      'totalTradedVolume': 274579,
#      'impliedVolatility': 28.49,
#      'lastPrice': 2.25,
#      'change': -2.25,
#      'pChange': -50,
#      'totalBuyQuantity': 97000,
#      'totalSellQuantity': 25200,
#      'bidQty': 875,
#      'bidprice': 2.2,
#      'askQty': 3200,
#      'askPrice': 2.25,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 45000,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 45000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE45000.00',
#      'openInterest': 21255,
#      'changeinOpenInterest': -1572,
#      'pchangeinOpenInterest': -6.886581679589959,
#      'totalTradedVolume': 169867,
#      'impliedVolatility': 32.64,
#      'lastPrice': 2.15,
#      'change': -1.65,
#      'pChange': -43.42105263157895,
#      'totalBuyQuantity': 136875,
#      'totalSellQuantity': 73200,
#      'bidQty': 1650,
#      'bidprice': 2.15,
#      'askQty': 25,
#      'askPrice': 2.2,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 45000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE45000.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 4800,
#      'totalSellQuantity': 6000,
#      'bidQty': 1500,
#      'bidprice': 3229.55,
#      'askQty': 750,
#      'askPrice': 3336.15,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 45500,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 45500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE45500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 0,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3600,
#      'totalSellQuantity': 4350,
#      'bidQty': 100,
#      'bidprice': 3666.4,
#      'askQty': 750,
#      'askPrice': 3833.5,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 45500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE45500.00',
#      'openInterest': 8815,
#      'changeinOpenInterest': -4582,
#      'pchangeinOpenInterest': -34.2016869448384,
#      'totalTradedVolume': 108128,
#      'impliedVolatility': 36.83,
#      'lastPrice': 2.15,
#      'change': -1.15,
#      'pChange': -34.848484848484844,
#      'totalBuyQuantity': 88175,
#      'totalSellQuantity': 28225,
#      'bidQty': 3350,
#      'bidprice': 2.15,
#      'askQty': 350,
#      'askPrice': 2.2,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 46000,
#     'expiryDate': '10-Nov-2022',
#     'CE': {'strikePrice': 46000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE46000.00',
#      'openInterest': 9355,
#      'changeinOpenInterest': 594,
#      'pchangeinOpenInterest': 6.780047939732907,
#      'totalTradedVolume': 85013,
#      'impliedVolatility': 40.93,
#      'lastPrice': 2.15,
#      'change': -1,
#      'pChange': -31.746031746031743,
#      'totalBuyQuantity': 69575,
#      'totalSellQuantity': 47000,
#      'bidQty': 16950,
#      'bidprice': 2.05,
#      'askQty': 800,
#      'askPrice': 2.1,
#      'underlyingValue': 41686.7},
#     'PE': {'strikePrice': 46000,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE46000.00',
#      'openInterest': 1,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 0,
#      'impliedVolatility': 0,
#      'lastPrice': 4553.2,
#      'change': 0,
#      'pChange': 0,
#      'totalBuyQuantity': 3100,
#      'totalSellQuantity': 4350,
#      'bidQty': 100,
#      'bidprice': 4186.7,
#      'askQty': 750,
#      'askPrice': 4330.75,
#      'underlyingValue': 41686.7}},
#    {'strikePrice': 46500,
#     'expiryDate': '10-Nov-2022',
#     'PE': {'strikePrice': 46500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022PE46500.00',
#      'openInterest': 0,
#      'changeinOpenInterest': 0,
#      'pchangeinOpenInterest': 0,
#      'totalTradedVolume': 2,
#      'impliedVolatility': 0,
#      'lastPrice': 4683.5,
#      'change': -2304.1000000000004,
#      'pChange': -32.974125593909214,
#      'totalBuyQuantity': 2925,
#      'totalSellQuantity': 4250,
#      'bidQty': 225,
#      'bidprice': 4690.5,
#      'askQty': 750,
#      'askPrice': 4874.1,
#      'underlyingValue': 41686.7},
#     'CE': {'strikePrice': 46500,
#      'expiryDate': '10-Nov-2022',
#      'underlying': 'BANKNIFTY',
#      'identifier': 'OPTIDXBANKNIFTY10-11-2022CE46500.00',
#      'openInterest': 27550,
#      'changeinOpenInterest': 10673,
#      'pchangeinOpenInterest': 63.239912306689575,
#      'totalTradedVolume': 152932,
#      'impliedVolatility': 44.94,
#      'lastPrice': 2.15,
#      'change': -0.75,
#      'pChange': -25.862068965517242,
#      'totalBuyQuantity': 104400,
#      'totalSellQuantity': 80775,
#      'bidQty': 150,
#      'bidprice': 2.15,
#      'askQty': 3975,
#      'askPrice': 2.25,
#      'underlyingValue': 41686.7}}],
#   'CE': {'totOI': 987248, 'totVol': 26311418},
#   'PE': {'totOI': 1084512, 'totVol': 26035465}}}

# %%
# headers={ 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
# session=requests.session()
# session.get("http://nseindia.com", headers = headers)

# %%
# json_obj = session.get(url, headers=headers).json()

# %%
df=json_normalize( json_obj["records"])
df
# Out:
#                                          expiryDates  \
# 0  [10-Nov-2022, 17-Nov-2022, 24-Nov-2022, 01-Dec...
#
#                                                 data             timestamp  \
# 0  [{'strikePrice': 25500, 'expiryDate': '29-Dec-...  07-Nov-2022 15:30:00
#
#    underlyingValue                                       strikePrices  \
# 0          41686.7  [25500, 27000, 28500, 29000, 29500, 30000, 305...
#
#           index.key index.index index.indexSymbol  index.last  \
# 0  SECTORAL INDICES  NIFTY BANK        NIFTY BANK     41686.7
#
#    index.variation  ...  index.low  index.previousClose  index.yearHigh  \
# 0           428.25  ...   41337.05             41258.45        41840.15
#
#    index.yearLow  index.pe  index.pb  index.dy index.declines index.advances  \
# 0       32155.35     17.41      2.75      0.67              4              8
#
#   index.unchanged
# 0               0
#
# [1 rows x 23 columns]

# %%
df_data=json_normalize( json_obj["records"]["data"])
# df_timestamp=json_normalize( json_obj["records"]["timestamp"])
# df_underlyingValue=json_normalize( json_obj["records"]["underlyingValue"])
# df_expiryDates=json_normalize( json_obj["records"]["expiryDates"])
df_strikePrices=json_normalize( json_obj["records"]["strikePrices"])

# %%
df_data
# Out:
#      strikePrice   expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 0          25500  29-Dec-2022         25500.0   29-Dec-2022     BANKNIFTY
# 1          25500  30-Mar-2023             NaN           NaN           NaN
# 2          25500  28-Sep-2023             NaN           NaN           NaN
# 3          25500  29-Jun-2023             NaN           NaN           NaN
# 4          27000  30-Mar-2023             NaN           NaN           NaN
# ..           ...          ...             ...           ...           ...
# 700        49500  29-Dec-2022         49500.0   29-Dec-2022     BANKNIFTY
# 701        49500  25-Jan-2023         49500.0   25-Jan-2023     BANKNIFTY
# 702        49500  30-Mar-2023         49500.0   30-Mar-2023     BANKNIFTY
# 703        49500  29-Jun-2023         49500.0   29-Jun-2023     BANKNIFTY
# 704        49500  28-Sep-2023         49500.0   28-Sep-2023     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 0    OPTIDXBANKNIFTY29-12-2022CE25500.00              0.0
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# ..                                   ...              ...
# 700  OPTIDXBANKNIFTY29-12-2022CE49500.00            824.0
# 701  OPTIDXBANKNIFTY25-01-2023CE49500.00              1.0
# 702  OPTIDXBANKNIFTY30-03-2023CE49500.00              0.0
# 703  OPTIDXBANKNIFTY29-06-2023CE49500.00              0.0
# 704  OPTIDXBANKNIFTY28-09-2023CE49500.00              0.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 0                        0.0                  0.000000                   0.0
# 1                        NaN                       NaN                   NaN
# 2                        NaN                       NaN                   NaN
# 3                        NaN                       NaN                   NaN
# 4                        NaN                       NaN                   NaN
# ..                       ...                       ...                   ...
# 700                     79.0                 10.604027                 479.0
# 701                      0.0                  0.000000                   0.0
# 702                      0.0                  0.000000                   0.0
# 703                      0.0                  0.000000                   0.0
# 704                      0.0                  0.000000                   0.0
#
#      ...  PE.lastPrice  PE.change  PE.pChange  PE.totalBuyQuantity  \
# 0    ...           0.0        0.0         0.0              16600.0
# 1    ...           0.0        0.0         0.0               1000.0
# 2    ...           0.0        0.0         0.0               1000.0
# 3    ...           0.0        0.0         0.0                900.0
# 4    ...           0.0        0.0         0.0                975.0
# ..   ...           ...        ...         ...                  ...
# 700  ...           0.0        0.0         0.0               1775.0
# 701  ...           NaN        NaN         NaN                  NaN
# 702  ...           NaN        NaN         NaN                  NaN
# 703  ...           NaN        NaN         NaN                  NaN
# 704  ...           NaN        NaN         NaN                  NaN
#
#      PE.totalSellQuantity  PE.bidQty  PE.bidprice  PE.askQty  PE.askPrice  \
# 0                     0.0     5400.0         1.10        0.0         0.00
# 1                     0.0      900.0         2.25        0.0         0.00
# 2                     0.0      900.0         0.70        0.0         0.00
# 3                     0.0      900.0         1.20        0.0         0.00
# 4                     0.0      900.0         1.70        0.0         0.00
# ..                    ...        ...          ...        ...          ...
# 700                1775.0      875.0      7139.15      875.0      8524.45
# 701                   NaN        NaN          NaN        NaN          NaN
# 702                   NaN        NaN          NaN        NaN          NaN
# 703                   NaN        NaN          NaN        NaN          NaN
# 704                   NaN        NaN          NaN        NaN          NaN
#
#      PE.underlyingValue
# 0               41686.7
# 1               41686.7
# 2               41686.7
# 3               41686.7
# 4               41686.7
# ..                  ...
# 700             41686.7
# 701                 NaN
# 702                 NaN
# 703                 NaN
# 704                 NaN
#
# [705 rows x 40 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   strikePrice               705 non-null    int64
#  1   expiryDate                705 non-null    object
#  2   CE.strikePrice            634 non-null    float64
#  3   CE.expiryDate             634 non-null    object
#  4   CE.underlying             634 non-null    object
#  5   CE.identifier             634 non-null    object
#  6   CE.openInterest           634 non-null    float64
#  7   CE.changeinOpenInterest   634 non-null    float64
#  8   CE.pchangeinOpenInterest  634 non-null    float64
#  9   CE.totalTradedVolume      634 non-null    float64
#  10  CE.impliedVolatility      634 non-null    float64
#  11  CE.lastPrice              634 non-null    float64
#  12  CE.change                 634 non-null    float64
#  13  CE.pChange                634 non-null    float64
#  14  CE.totalBuyQuantity       634 non-null    float64
#  15  CE.totalSellQuantity      634 non-null    float64
#  16  CE.bidQty                 634 non-null    float64
#  17  CE.bidprice               634 non-null    float64
#  18  CE.askQty                 634 non-null    float64
#  19  CE.askPrice               634 non-null    float64
#  20  CE.underlyingValue        634 non-null    float64
#  21  PE.strikePrice            631 non-null    float64
#  22  PE.expiryDate             631 non-null    object
#  23  PE.underlying             631 non-null    object
#  24  PE.identifier             631 non-null    object
#  25  PE.openInterest           631 non-null    float64
#  26  PE.changeinOpenInterest   631 non-null    float64
#  27  PE.pchangeinOpenInterest  631 non-null    float64
#  28  PE.totalTradedVolume      631 non-null    float64
#  29  PE.impliedVolatility      631 non-null    float64
#  30  PE.lastPrice              631 non-null    float64
#  31  PE.change                 631 non-null    float64
#  32  PE.pChange                631 non-null    float64
#  33  PE.totalBuyQuantity       631 non-null    float64
#  34  PE.totalSellQuantity      631 non-null    float64
#  35  PE.bidQty                 631 non-null    float64
#  36  PE.bidprice               631 non-null    float64
#  37  PE.askQty                 631 non-null    float64
#  38  PE.askPrice               631 non-null    float64
#  39  PE.underlyingValue        631 non-null    float64
# dtypes: float64(32), int64(1), object(7)
# memory usage: 220.4+ KB

# %%
for i in df_data.columns:
    if "Date" in i:
        df_data[i]= pd.to_datetime(df_data[i])

# %%
df_data
# Out:
#      strikePrice expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 0          25500 2022-12-29         25500.0    2022-12-29     BANKNIFTY
# 1          25500 2023-03-30             NaN           NaT           NaN
# 2          25500 2023-09-28             NaN           NaT           NaN
# 3          25500 2023-06-29             NaN           NaT           NaN
# 4          27000 2023-03-30             NaN           NaT           NaN
# ..           ...        ...             ...           ...           ...
# 700        49500 2022-12-29         49500.0    2022-12-29     BANKNIFTY
# 701        49500 2023-01-25         49500.0    2023-01-25     BANKNIFTY
# 702        49500 2023-03-30         49500.0    2023-03-30     BANKNIFTY
# 703        49500 2023-06-29         49500.0    2023-06-29     BANKNIFTY
# 704        49500 2023-09-28         49500.0    2023-09-28     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 0    OPTIDXBANKNIFTY29-12-2022CE25500.00              0.0
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# ..                                   ...              ...
# 700  OPTIDXBANKNIFTY29-12-2022CE49500.00            824.0
# 701  OPTIDXBANKNIFTY25-01-2023CE49500.00              1.0
# 702  OPTIDXBANKNIFTY30-03-2023CE49500.00              0.0
# 703  OPTIDXBANKNIFTY29-06-2023CE49500.00              0.0
# 704  OPTIDXBANKNIFTY28-09-2023CE49500.00              0.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 0                        0.0                  0.000000                   0.0
# 1                        NaN                       NaN                   NaN
# 2                        NaN                       NaN                   NaN
# 3                        NaN                       NaN                   NaN
# 4                        NaN                       NaN                   NaN
# ..                       ...                       ...                   ...
# 700                     79.0                 10.604027                 479.0
# 701                      0.0                  0.000000                   0.0
# 702                      0.0                  0.000000                   0.0
# 703                      0.0                  0.000000                   0.0
# 704                      0.0                  0.000000                   0.0
#
#      ...  PE.lastPrice  PE.change  PE.pChange  PE.totalBuyQuantity  \
# 0    ...           0.0        0.0         0.0              16600.0
# 1    ...           0.0        0.0         0.0               1000.0
# 2    ...           0.0        0.0         0.0               1000.0
# 3    ...           0.0        0.0         0.0                900.0
# 4    ...           0.0        0.0         0.0                975.0
# ..   ...           ...        ...         ...                  ...
# 700  ...           0.0        0.0         0.0               1775.0
# 701  ...           NaN        NaN         NaN                  NaN
# 702  ...           NaN        NaN         NaN                  NaN
# 703  ...           NaN        NaN         NaN                  NaN
# 704  ...           NaN        NaN         NaN                  NaN
#
#      PE.totalSellQuantity  PE.bidQty  PE.bidprice  PE.askQty  PE.askPrice  \
# 0                     0.0     5400.0         1.10        0.0         0.00
# 1                     0.0      900.0         2.25        0.0         0.00
# 2                     0.0      900.0         0.70        0.0         0.00
# 3                     0.0      900.0         1.20        0.0         0.00
# 4                     0.0      900.0         1.70        0.0         0.00
# ..                    ...        ...          ...        ...          ...
# 700                1775.0      875.0      7139.15      875.0      8524.45
# 701                   NaN        NaN          NaN        NaN          NaN
# 702                   NaN        NaN          NaN        NaN          NaN
# 703                   NaN        NaN          NaN        NaN          NaN
# 704                   NaN        NaN          NaN        NaN          NaN
#
#      PE.underlyingValue
# 0               41686.7
# 1               41686.7
# 2               41686.7
# 3               41686.7
# 4               41686.7
# ..                  ...
# 700             41686.7
# 701                 NaN
# 702                 NaN
# 703                 NaN
# 704                 NaN
#
# [705 rows x 40 columns]

# %%
df_data_n=df_data[df_data["expiryDate"]=="2022-11-10"]

# %% [raw]
# df_data_n.to_excel("3Nov22.xlsx")

# %%
df_data_n
# Out:
#      strikePrice expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 21         30500 2022-11-10         30500.0    2022-11-10     BANKNIFTY
# 24         31000 2022-11-10         31000.0    2022-11-10     BANKNIFTY
# 34         31500 2022-11-10         31500.0    2022-11-10     BANKNIFTY
# 40         32000 2022-11-10         32000.0    2022-11-10     BANKNIFTY
# 49         32500 2022-11-10         32500.0    2022-11-10     BANKNIFTY
# ..           ...        ...             ...           ...           ...
# 637        44500 2022-11-10         44500.0    2022-11-10     BANKNIFTY
# 655        45000 2022-11-10         45000.0    2022-11-10     BANKNIFTY
# 672        45500 2022-11-10         45500.0    2022-11-10     BANKNIFTY
# 674        46000 2022-11-10         46000.0    2022-11-10     BANKNIFTY
# 681        46500 2022-11-10         46500.0    2022-11-10     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 21   OPTIDXBANKNIFTY10-11-2022CE30500.00              0.0
# 24   OPTIDXBANKNIFTY10-11-2022CE31000.00              0.0
# 34   OPTIDXBANKNIFTY10-11-2022CE31500.00              0.0
# 40   OPTIDXBANKNIFTY10-11-2022CE32000.00              0.0
# 49   OPTIDXBANKNIFTY10-11-2022CE32500.00              0.0
# ..                                   ...              ...
# 637  OPTIDXBANKNIFTY10-11-2022CE44500.00          37441.0
# 655  OPTIDXBANKNIFTY10-11-2022CE45000.00          21255.0
# 672  OPTIDXBANKNIFTY10-11-2022CE45500.00           8815.0
# 674  OPTIDXBANKNIFTY10-11-2022CE46000.00           9355.0
# 681  OPTIDXBANKNIFTY10-11-2022CE46500.00          27550.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 21                       0.0                  0.000000                   0.0
# 24                       0.0                  0.000000                   0.0
# 34                       0.0                  0.000000                   0.0
# 40                       0.0                  0.000000                   0.0
# 49                       0.0                  0.000000                   0.0
# ..                       ...                       ...                   ...
# 637                 -18937.0                -33.589343              274579.0
# 655                  -1572.0                 -6.886582              169867.0
# 672                  -4582.0                -34.201687              108128.0
# 674                    594.0                  6.780048               85013.0
# 681                  10673.0                 63.239912              152932.0
#
#      ...  PE.lastPrice  PE.change  PE.pChange  PE.totalBuyQuantity  \
# 21   ...          1.30      -0.35  -21.212121             511075.0
# 24   ...          1.35      -0.30  -18.181818             179475.0
# 34   ...          1.60      -0.10   -5.882353              50650.0
# 40   ...          1.30      -0.45  -25.714286              88075.0
# 49   ...          1.40      -0.40  -22.222222              51900.0
# ..   ...           ...        ...         ...                  ...
# 637  ...       2828.00    -488.95  -14.740952               4775.0
# 655  ...          0.00       0.00    0.000000               4800.0
# 672  ...          0.00       0.00    0.000000               3600.0
# 674  ...       4553.20       0.00    0.000000               3100.0
# 681  ...       4683.50   -2304.10  -32.974126               2925.0
#
#      PE.totalSellQuantity  PE.bidQty  PE.bidprice  PE.askQty  PE.askPrice  \
# 21               289575.0    31075.0         1.25    45450.0         1.30
# 24                88750.0    50525.0         1.25     7525.0         1.35
# 34                 3950.0     1100.0         1.40     1800.0         1.60
# 40                20350.0    10400.0         1.30      225.0         1.40
# 49                 4675.0     9275.0         1.30     1850.0         1.40
# ..                    ...        ...          ...        ...          ...
# 637                6000.0     2100.0      2673.30      750.0      2812.90
# 655                6000.0     1500.0      3229.55      750.0      3336.15
# 672                4350.0      100.0      3666.40      750.0      3833.50
# 674                4350.0      100.0      4186.70      750.0      4330.75
# 681                4250.0      225.0      4690.50      750.0      4874.10
#
#      PE.underlyingValue
# 21              41686.7
# 24              41686.7
# 34              41686.7
# 40              41686.7
# 49              41686.7
# ..                  ...
# 637             41686.7
# 655             41686.7
# 672             41686.7
# 674             41686.7
# 681             41686.7
#
# [98 rows x 40 columns]

# %%
df_data_n["Difference"]=df_data_n["CE.underlyingValue"]-df_data_n["CE.strikePrice"]
df_data_n["Ratio"]=df_data_n["CE.openInterest"]/df_data_n["PE.openInterest"]
# Out:
# <ipython-input-14-0ce08887058e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_n["Difference"]=df_data_n["CE.underlyingValue"]-df_data_n["CE.strikePrice"]
# <ipython-input-14-0ce08887058e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_n["Ratio"]=df_data_n["CE.openInterest"]/df_data_n["PE.openInterest"]

# %%
df_call=df_data_n[df_data_n["Difference"]<0].iloc[3:]
df_put=df_data_n[df_data_n["Difference"]>0].iloc[:-3]

# %%
df_call_1=df_call.sort_values(by=["CE.openInterest"],ascending=False).iloc[:13].sort_values(by=['Ratio'],ascending=False)
df_put_1=df_put.sort_values(by=["PE.openInterest"],ascending=False).iloc[:13].sort_values(by=['Ratio'])

# %%
df_put_1
# Out:
#      strikePrice expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 21         30500 2022-11-10         30500.0    2022-11-10     BANKNIFTY
# 312        39000 2022-11-10         39000.0    2022-11-10     BANKNIFTY
# 346        39500 2022-11-10         39500.0    2022-11-10     BANKNIFTY
# 254        38000 2022-11-10         38000.0    2022-11-10     BANKNIFTY
# 434        40700 2022-11-10         40700.0    2022-11-10     BANKNIFTY
# 384        40000 2022-11-10         40000.0    2022-11-10     BANKNIFTY
# 428        40600 2022-11-10         40600.0    2022-11-10     BANKNIFTY
# 422        40500 2022-11-10         40500.0    2022-11-10     BANKNIFTY
# 442        40800 2022-11-10         40800.0    2022-11-10     BANKNIFTY
# 460        41100 2022-11-10         41100.0    2022-11-10     BANKNIFTY
# 454        41000 2022-11-10         41000.0    2022-11-10     BANKNIFTY
# 467        41200 2022-11-10         41200.0    2022-11-10     BANKNIFTY
# 474        41300 2022-11-10         41300.0    2022-11-10     BANKNIFTY
#
#                            CE.identifier  CE.openInterest  \
# 21   OPTIDXBANKNIFTY10-11-2022CE30500.00              0.0
# 312  OPTIDXBANKNIFTY10-11-2022CE39000.00            591.0
# 346  OPTIDXBANKNIFTY10-11-2022CE39500.00           1011.0
# 254  OPTIDXBANKNIFTY10-11-2022CE38000.00            710.0
# 434  OPTIDXBANKNIFTY10-11-2022CE40700.00            889.0
# 384  OPTIDXBANKNIFTY10-11-2022CE40000.00           1950.0
# 428  OPTIDXBANKNIFTY10-11-2022CE40600.00            989.0
# 422  OPTIDXBANKNIFTY10-11-2022CE40500.00           3377.0
# 442  OPTIDXBANKNIFTY10-11-2022CE40800.00           5306.0
# 460  OPTIDXBANKNIFTY10-11-2022CE41100.00           4506.0
# 454  OPTIDXBANKNIFTY10-11-2022CE41000.00          10661.0
# 467  OPTIDXBANKNIFTY10-11-2022CE41200.00          10554.0
# 474  OPTIDXBANKNIFTY10-11-2022CE41300.00          13623.0
#
#      CE.changeinOpenInterest  CE.pchangeinOpenInterest  CE.totalTradedVolume  \
# 21                       0.0                  0.000000                   0.0
# 312                     14.0                  2.426343                 105.0
# 346                    -77.0                 -7.077206                 396.0
# 254                    -42.0                 -5.585106                  58.0
# 434                     77.0                  9.482759                5750.0
# 384                   -399.0                -16.985951                6405.0
# 428                   -244.0                -19.789132                2688.0
# 422                  -1272.0                -27.360723               14363.0
# 442                  -1117.0                -17.390627               16945.0
# 460                  -9133.0                -66.962387              125018.0
# 454                 -23890.0                -69.144164              282025.0
# 467                 -24116.0                -69.558696              397250.0
# 474                 -42308.0                -75.643203              790857.0
#
#      ...  PE.pChange  PE.totalBuyQuantity  PE.totalSellQuantity  PE.bidQty  \
# 21   ...  -21.212121             511075.0              289575.0    31075.0
# 312  ...  -52.980132             189300.0               63925.0       25.0
# 346  ...  -68.978102             170900.0               30975.0      125.0
# 254  ...  -25.000000             126575.0               38575.0     1300.0
# 434  ...  -86.585843              72975.0               27300.0       50.0
# 384  ...  -81.155015             137750.0              102525.0      125.0
# 428  ...  -86.811116              85800.0               25525.0       75.0
# 422  ...  -86.277873             158225.0               78500.0       50.0
# 442  ...  -84.742468              86225.0               57050.0       75.0
# 460  ...  -80.707828             123700.0              113650.0      150.0
# 454  ...  -82.810368             120350.0              200050.0      300.0
# 467  ...  -77.541528             122775.0              127775.0       25.0
# 474  ...  -75.886423             130375.0              113000.0       50.0
#
#      PE.bidprice  PE.askQty  PE.askPrice  PE.underlyingValue  Difference  \
# 21          1.25    45450.0         1.30             41686.7     11186.7
# 312         3.55     1425.0         3.70             41686.7      2686.7
# 346         4.25      550.0         4.50             41686.7      2186.7
# 254         2.70     3750.0         3.00             41686.7      3686.7
# 434        17.15      225.0        18.65             41686.7       986.7
# 384         6.20      900.0         6.45             41686.7      1686.7
# 428        14.00       25.0        14.80             41686.7      1086.7
# 422        11.40      175.0        12.00             41686.7      1186.7
# 442        22.45       25.0        23.15             41686.7       886.7
# 460        50.00       50.0        52.15             41686.7       586.7
# 454        38.10       50.0        39.85             41686.7       686.7
# 467        66.00       50.0        67.90             41686.7       486.7
# 474        83.65      475.0        86.60             41686.7       386.7
#
#         Ratio
# 21   0.000000
# 312  0.010765
# 346  0.020833
# 254  0.023829
# 434  0.026061
# 384  0.027041
# 428  0.038200
# 422  0.057869
# 442  0.125744
# 460  0.135092
# 454  0.157335
# 467  0.286334
# 474  0.390467
#
# [13 rows x 42 columns]

# %% [raw]
# df_test = pd.read_excel("3Nov22.xlsx",sheet_name=None)
# df_call=df_test["Call"]
# df_put=df_test["Put"]
# df_call_1=df_test["Call 1"]
# df_put_1=df_test["Put 1"]

# %%
def OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy):
    try:
        Max_Profit=round((CE_Sell+PE_Sell-CE_Buy-PE_Buy)*50,2)
        Max_Loss=round((CE_Sell+PE_Sell-CE_Buy-PE_Buy-200)*50,2)
        List=[Max_Profit,Max_Loss,round(-Max_Loss/Max_Profit,2)]
    except Exception as e:
        return [str(e),str(e),str(e)]
    else:
        return List

# %%
def CallPrice(StrikePrice,Data):
    try:
        df=Data[Data["CE.strikePrice"]==StrikePrice]["CE.lastPrice"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

def PutPrice(StrikePrice,Data):
    try:
        df=Data[Data["PE.strikePrice"]==StrikePrice]["PE.lastPrice"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

def CE_OpenInterest(StrikePrice,Data):
    try:
        df=Data[Data["CE.strikePrice"]==StrikePrice]["CE.openInterest"].iloc[0]
    except Exception as e:
        return e
    else:
        return df
    
def PE_OpenInterest(StrikePrice,Data):
    try:
        df=Data[Data["PE.strikePrice"]==StrikePrice]["PE.openInterest"].iloc[0]
    except Exception as e:
        return e
    else:
        return df

# %% [raw]
# my_columns = ["CE StrikePrice", 'PE StrikePrice',"CE StrikePrice 1", 'PE StrikePrice 1','Max Profit', 'Max Loss', "Risk/Reward"]
# final_dataframe = pd.DataFrame(columns = my_columns)
# final_dataframe
#
# for i in df_call_1["CE.strikePrice"]:
#     l=[]
#     l.append(i)
#     for j in df_put_1["PE.strikePrice"]:
#         l.append(j)
#         l.append(l[0]+200)
#         l.append(l[1]-200)
#         CE_Sell=CallPrice(l[0],df_call)
#         PE_Sell=PutPrice(l[1],df_put)
#         CE_Buy=CallPrice(l[2],df_call)
#         PE_Buy=PutPrice(l[3],df_put)
#         l=l+OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy)
#         final_dataframe = final_dataframe.append(
#                                         pd.Series(l,index = my_columns),
#                                         ignore_index = True)
#         l=[i]

# %%
my_columns = ["CE StrikePrice", "CE OpenInterest",'PE StrikePrice',"PE OpenInterest","CE StrikePrice 1","CE OpenInterest 1", 'PE StrikePrice 1',"PE OpenInterest 1",'Max Profit', 'Max Loss', "Risk/Reward"]
final_dataframe = pd.DataFrame(columns = my_columns)


for i in df_call_1["CE.strikePrice"]:
    l=[]
    l.append(i)
    l.append(CE_OpenInterest(i,df_data_n))
    for j in df_put_1["PE.strikePrice"]:
        l.append(j)
        l.append(PE_OpenInterest(j,df_data_n))
        
        l.append(l[0]+200)
        l.append(CE_OpenInterest(l[0]+200,df_data_n))
        
        l.append(l[2]-200)
        l.append(PE_OpenInterest(l[2]-200,df_data_n))
        
        CE_Sell=CallPrice(l[0],df_data_n)
        PE_Sell=PutPrice(l[2],df_data_n)
        CE_Buy=CallPrice(l[4],df_data_n)
        PE_Buy=PutPrice(l[6],df_data_n)
        l=l+OverView(CE_Sell,PE_Sell,CE_Buy,PE_Buy)
        final_dataframe = final_dataframe.append(
                                        pd.Series(l,index = my_columns), 
                                        ignore_index = True)
        l=[i,CE_OpenInterest(i,df_data_n)]
# Out:
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# <ipython-input-20-6362eb3418d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(

# %%
final_dataframe['Risk/Reward'] = pd.to_numeric(final_dataframe['Risk/Reward'], errors="coerce")
final_dataframe.dropna(how="any", inplace=True)

# %%
df=final_dataframe[final_dataframe["Risk/Reward"]<=5][final_dataframe["Risk/Reward"]>0]
# Out:
# <ipython-input-22-e887e948a436>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df=final_dataframe[final_dataframe["Risk/Reward"]<=5][final_dataframe["Risk/Reward"]>0]

# %%
df.sort_values(by=["Risk/Reward"])
# Out:
#     CE StrikePrice CE OpenInterest PE StrikePrice PE OpenInterest  \
# 168        42000.0         77672.0        41300.0         34889.0
# 167        42000.0         77672.0        41200.0         36859.0
# 155        42100.0         25074.0        41300.0         34889.0
# 165        42000.0         77672.0        41100.0         33355.0
# 154        42100.0         25074.0        41200.0         36859.0
# 166        42000.0         77672.0        41000.0         67760.0
# 164        42000.0         77672.0        40800.0         42197.0
# 152        42100.0         25074.0        41100.0         33355.0
# 142        42200.0         35081.0        41300.0         34889.0
# 160        42000.0         77672.0        40700.0         34112.0
# 162        42000.0         77672.0        40600.0         25890.0
# 163        42000.0         77672.0        40500.0         58356.0
# 141        42200.0         35081.0        41200.0         36859.0
# 153        42100.0         25074.0        41000.0         67760.0
# 161        42000.0         77672.0        40000.0         72114.0
# 159        42000.0         77672.0        38000.0         29796.0
# 158        42000.0         77672.0        39500.0         48528.0
# 157        42000.0         77672.0        39000.0         54901.0
# 151        42100.0         25074.0        40800.0         42197.0
# 129        42300.0         30162.0        41300.0         34889.0
# 147        42100.0         25074.0        40700.0         34112.0
# 128        42300.0         30162.0        41200.0         36859.0
# 103        42400.0         26455.0        41300.0         34889.0
# 139        42200.0         35081.0        41100.0         33355.0
# 150        42100.0         25074.0        40500.0         58356.0
# 149        42100.0         25074.0        40600.0         25890.0
# 148        42100.0         25074.0        40000.0         72114.0
# 102        42400.0         26455.0        41200.0         36859.0
# 146        42100.0         25074.0        38000.0         29796.0
# 144        42100.0         25074.0        39000.0         54901.0
# 145        42100.0         25074.0        39500.0         48528.0
# 140        42200.0         35081.0        41000.0         67760.0
# 116        42500.0         66271.0        41300.0         34889.0
# 115        42500.0         66271.0        41200.0         36859.0
# 126        42300.0         30162.0        41100.0         33355.0
# 138        42200.0         35081.0        40800.0         42197.0
# 90         42600.0         21545.0        41300.0         34889.0
# 100        42400.0         26455.0        41100.0         33355.0
# 134        42200.0         35081.0        40700.0         34112.0
# 127        42300.0         30162.0        41000.0         67760.0
# 89         42600.0         21545.0        41200.0         36859.0
# 64         42800.0         22927.0        41300.0         34889.0
# 137        42200.0         35081.0        40500.0         58356.0
# 136        42200.0         35081.0        40600.0         25890.0
# 77         43000.0         81767.0        41300.0         34889.0
# 135        42200.0         35081.0        40000.0         72114.0
# 101        42400.0         26455.0        41000.0         67760.0
# 133        42200.0         35081.0        38000.0         29796.0
# 63         42800.0         22927.0        41200.0         36859.0
# 113        42500.0         66271.0        41100.0         33355.0
# 132        42200.0         35081.0        39500.0         48528.0
# 131        42200.0         35081.0        39000.0         54901.0
#
#     CE StrikePrice 1 CE OpenInterest 1 PE StrikePrice 1 PE OpenInterest 1  \
# 168          42200.0           35081.0          41100.0           33355.0
# 167          42200.0           35081.0          41000.0           67760.0
# 155          42300.0           30162.0          41100.0           33355.0
# 165          42200.0           35081.0          40900.0           22684.0
# 154          42300.0           30162.0          41000.0           67760.0
# 166          42200.0           35081.0          40800.0           42197.0
# 164          42200.0           35081.0          40600.0           25890.0
# 152          42300.0           30162.0          40900.0           22684.0
# 142          42400.0           26455.0          41100.0           33355.0
# 160          42200.0           35081.0          40500.0           58356.0
# 162          42200.0           35081.0          40400.0           15377.0
# 163          42200.0           35081.0          40300.0           15202.0
# 141          42400.0           26455.0          41000.0           67760.0
# 153          42300.0           30162.0          40800.0           42197.0
# 161          42200.0           35081.0          39800.0           16332.0
# 159          42200.0           35081.0          37800.0             933.0
# 158          42200.0           35081.0          39300.0            5606.0
# 157          42200.0           35081.0          38800.0            4696.0
# 151          42300.0           30162.0          40600.0           25890.0
# 129          42500.0           66271.0          41100.0           33355.0
# 147          42300.0           30162.0          40500.0           58356.0
# 128          42500.0           66271.0          41000.0           67760.0
# 103          42600.0           21545.0          41100.0           33355.0
# 139          42400.0           26455.0          40900.0           22684.0
# 150          42300.0           30162.0          40300.0           15202.0
# 149          42300.0           30162.0          40400.0           15377.0
# 148          42300.0           30162.0          39800.0           16332.0
# 102          42600.0           21545.0          41000.0           67760.0
# 146          42300.0           30162.0          37800.0             933.0
# 144          42300.0           30162.0          38800.0            4696.0
# 145          42300.0           30162.0          39300.0            5606.0
# 140          42400.0           26455.0          40800.0           42197.0
# 116          42700.0           19029.0          41100.0           33355.0
# 115          42700.0           19029.0          41000.0           67760.0
# 126          42500.0           66271.0          40900.0           22684.0
# 138          42400.0           26455.0          40600.0           25890.0
# 90           42800.0           22927.0          41100.0           33355.0
# 100          42600.0           21545.0          40900.0           22684.0
# 134          42400.0           26455.0          40500.0           58356.0
# 127          42500.0           66271.0          40800.0           42197.0
# 89           42800.0           22927.0          41000.0           67760.0
# 64           43000.0           81767.0          41100.0           33355.0
# 137          42400.0           26455.0          40300.0           15202.0
# 136          42400.0           26455.0          40400.0           15377.0
# 77           43200.0           12326.0          41100.0           33355.0
# 135          42400.0           26455.0          39800.0           16332.0
# 101          42600.0           21545.0          40800.0           42197.0
# 133          42400.0           26455.0          37800.0             933.0
# 63           43000.0           81767.0          41000.0           67760.0
# 113          42700.0           19029.0          40900.0           22684.0
# 132          42400.0           26455.0          39300.0            5606.0
# 131          42400.0           26455.0          38800.0            4696.0
#
#     Max Profit Max Loss  Risk/Reward
# 168     4675.0  -5325.0         1.14
# 167     4490.0  -5510.0         1.23
# 155     4125.0  -5875.0         1.42
# 165     3977.5  -6022.5         1.51
# 154     3940.0  -6060.0         1.54
# 166     3712.5  -6287.5         1.69
# 164     3477.5  -6522.5         1.88
# 152     3427.5  -6572.5         1.92
# 142     3350.0  -6650.0         1.99
# 160     3257.5  -6742.5         2.07
# 162     3195.0  -6805.0         2.13
# 163     3195.0  -6805.0         2.13
# 141     3165.0  -6835.0         2.16
# 153     3162.5  -6837.5         2.16
# 161     3042.5  -6957.5         2.29
# 159     3017.5  -6982.5         2.31
# 158     3012.5  -6987.5         2.32
# 157     3012.5  -6987.5         2.32
# 151     2927.5  -7072.5         2.42
# 129     2862.5  -7137.5         2.49
# 147     2707.5  -7292.5         2.69
# 128     2677.5  -7322.5         2.73
# 103     2675.0  -7325.0         2.74
# 139     2652.5  -7347.5         2.77
# 150     2645.0  -7355.0         2.78
# 149     2645.0  -7355.0         2.78
# 148     2492.5  -7507.5         3.01
# 102     2490.0  -7510.0         3.02
# 146     2467.5  -7532.5         3.05
# 144     2462.5  -7537.5         3.06
# 145     2462.5  -7537.5         3.06
# 140     2387.5  -7612.5         3.19
# 116     2387.5  -7612.5         3.19
# 115     2202.5  -7797.5         3.54
# 126     2165.0  -7835.0         3.62
# 138     2152.5  -7847.5         3.65
# 90      2082.5  -7917.5         3.80
# 100     1977.5  -8022.5         4.06
# 134     1932.5  -8067.5         4.17
# 127     1900.0  -8100.0         4.26
# 89      1897.5  -8102.5         4.27
# 64      1877.5  -8122.5         4.33
# 137     1870.0  -8130.0         4.35
# 136     1870.0  -8130.0         4.35
# 77      1762.5  -8237.5         4.67
# 135     1717.5  -8282.5         4.82
# 101     1712.5  -8287.5         4.84
# 133     1692.5  -8307.5         4.91
# 63      1692.5  -8307.5         4.91
# 113     1690.0  -8310.0         4.92
# 132     1687.5  -8312.5         4.93
# 131     1687.5  -8312.5         4.93

# %%
df["%diff"]=  (df["CE StrikePrice"]/df["PE StrikePrice"]-1)*100

# %%
df
# Out:
#     CE StrikePrice CE OpenInterest PE StrikePrice PE OpenInterest  \
# 63         42800.0         22927.0        41200.0         36859.0
# 64         42800.0         22927.0        41300.0         34889.0
# 77         43000.0         81767.0        41300.0         34889.0
# 89         42600.0         21545.0        41200.0         36859.0
# 90         42600.0         21545.0        41300.0         34889.0
# 100        42400.0         26455.0        41100.0         33355.0
# 101        42400.0         26455.0        41000.0         67760.0
# 102        42400.0         26455.0        41200.0         36859.0
# 103        42400.0         26455.0        41300.0         34889.0
# 113        42500.0         66271.0        41100.0         33355.0
# 115        42500.0         66271.0        41200.0         36859.0
# 116        42500.0         66271.0        41300.0         34889.0
# 126        42300.0         30162.0        41100.0         33355.0
# 127        42300.0         30162.0        41000.0         67760.0
# 128        42300.0         30162.0        41200.0         36859.0
# 129        42300.0         30162.0        41300.0         34889.0
# 131        42200.0         35081.0        39000.0         54901.0
# 132        42200.0         35081.0        39500.0         48528.0
# 133        42200.0         35081.0        38000.0         29796.0
# 134        42200.0         35081.0        40700.0         34112.0
# 135        42200.0         35081.0        40000.0         72114.0
# 136        42200.0         35081.0        40600.0         25890.0
# 137        42200.0         35081.0        40500.0         58356.0
# 138        42200.0         35081.0        40800.0         42197.0
# 139        42200.0         35081.0        41100.0         33355.0
# 140        42200.0         35081.0        41000.0         67760.0
# 141        42200.0         35081.0        41200.0         36859.0
# 142        42200.0         35081.0        41300.0         34889.0
# 144        42100.0         25074.0        39000.0         54901.0
# 145        42100.0         25074.0        39500.0         48528.0
# 146        42100.0         25074.0        38000.0         29796.0
# 147        42100.0         25074.0        40700.0         34112.0
# 148        42100.0         25074.0        40000.0         72114.0
# 149        42100.0         25074.0        40600.0         25890.0
# 150        42100.0         25074.0        40500.0         58356.0
# 151        42100.0         25074.0        40800.0         42197.0
# 152        42100.0         25074.0        41100.0         33355.0
# 153        42100.0         25074.0        41000.0         67760.0
# 154        42100.0         25074.0        41200.0         36859.0
# 155        42100.0         25074.0        41300.0         34889.0
# 157        42000.0         77672.0        39000.0         54901.0
# 158        42000.0         77672.0        39500.0         48528.0
# 159        42000.0         77672.0        38000.0         29796.0
# 160        42000.0         77672.0        40700.0         34112.0
# 161        42000.0         77672.0        40000.0         72114.0
# 162        42000.0         77672.0        40600.0         25890.0
# 163        42000.0         77672.0        40500.0         58356.0
# 164        42000.0         77672.0        40800.0         42197.0
# 165        42000.0         77672.0        41100.0         33355.0
# 166        42000.0         77672.0        41000.0         67760.0
# 167        42000.0         77672.0        41200.0         36859.0
# 168        42000.0         77672.0        41300.0         34889.0
#
#     CE StrikePrice 1 CE OpenInterest 1 PE StrikePrice 1 PE OpenInterest 1  \
# 63           43000.0           81767.0          41000.0           67760.0
# 64           43000.0           81767.0          41100.0           33355.0
# 77           43200.0           12326.0          41100.0           33355.0
# 89           42800.0           22927.0          41000.0           67760.0
# 90           42800.0           22927.0          41100.0           33355.0
# 100          42600.0           21545.0          40900.0           22684.0
# 101          42600.0           21545.0          40800.0           42197.0
# 102          42600.0           21545.0          41000.0           67760.0
# 103          42600.0           21545.0          41100.0           33355.0
# 113          42700.0           19029.0          40900.0           22684.0
# 115          42700.0           19029.0          41000.0           67760.0
# 116          42700.0           19029.0          41100.0           33355.0
# 126          42500.0           66271.0          40900.0           22684.0
# 127          42500.0           66271.0          40800.0           42197.0
# 128          42500.0           66271.0          41000.0           67760.0
# 129          42500.0           66271.0          41100.0           33355.0
# 131          42400.0           26455.0          38800.0            4696.0
# 132          42400.0           26455.0          39300.0            5606.0
# 133          42400.0           26455.0          37800.0             933.0
# 134          42400.0           26455.0          40500.0           58356.0
# 135          42400.0           26455.0          39800.0           16332.0
# 136          42400.0           26455.0          40400.0           15377.0
# 137          42400.0           26455.0          40300.0           15202.0
# 138          42400.0           26455.0          40600.0           25890.0
# 139          42400.0           26455.0          40900.0           22684.0
# 140          42400.0           26455.0          40800.0           42197.0
# 141          42400.0           26455.0          41000.0           67760.0
# 142          42400.0           26455.0          41100.0           33355.0
# 144          42300.0           30162.0          38800.0            4696.0
# 145          42300.0           30162.0          39300.0            5606.0
# 146          42300.0           30162.0          37800.0             933.0
# 147          42300.0           30162.0          40500.0           58356.0
# 148          42300.0           30162.0          39800.0           16332.0
# 149          42300.0           30162.0          40400.0           15377.0
# 150          42300.0           30162.0          40300.0           15202.0
# 151          42300.0           30162.0          40600.0           25890.0
# 152          42300.0           30162.0          40900.0           22684.0
# 153          42300.0           30162.0          40800.0           42197.0
# 154          42300.0           30162.0          41000.0           67760.0
# 155          42300.0           30162.0          41100.0           33355.0
# 157          42200.0           35081.0          38800.0            4696.0
# 158          42200.0           35081.0          39300.0            5606.0
# 159          42200.0           35081.0          37800.0             933.0
# 160          42200.0           35081.0          40500.0           58356.0
# 161          42200.0           35081.0          39800.0           16332.0
# 162          42200.0           35081.0          40400.0           15377.0
# 163          42200.0           35081.0          40300.0           15202.0
# 164          42200.0           35081.0          40600.0           25890.0
# 165          42200.0           35081.0          40900.0           22684.0
# 166          42200.0           35081.0          40800.0           42197.0
# 167          42200.0           35081.0          41000.0           67760.0
# 168          42200.0           35081.0          41100.0           33355.0
#
#     Max Profit Max Loss  Risk/Reward      %diff
# 63      1692.5  -8307.5         4.91   3.883495
# 64      1877.5  -8122.5         4.33   3.631961
# 77      1762.5  -8237.5         4.67   4.116223
# 89      1897.5  -8102.5         4.27   3.398058
# 90      2082.5  -7917.5         3.80     3.1477
# 100     1977.5  -8022.5         4.06   3.163017
# 101     1712.5  -8287.5         4.84   3.414634
# 102     2490.0  -7510.0         3.02   2.912621
# 103     2675.0  -7325.0         2.74   2.663438
# 113     1690.0  -8310.0         4.92   3.406326
# 115     2202.5  -7797.5         3.54    3.15534
# 116     2387.5  -7612.5         3.19   2.905569
# 126     2165.0  -7835.0         3.62   2.919708
# 127     1900.0  -8100.0         4.26   3.170732
# 128     2677.5  -7322.5         2.73   2.669903
# 129     2862.5  -7137.5         2.49   2.421308
# 131     1687.5  -8312.5         4.93   8.205128
# 132     1687.5  -8312.5         4.93   6.835443
# 133     1692.5  -8307.5         4.91  11.052632
# 134     1932.5  -8067.5         4.17   3.685504
# 135     1717.5  -8282.5         4.82        5.5
# 136     1870.0  -8130.0         4.35   3.940887
# 137     1870.0  -8130.0         4.35   4.197531
# 138     2152.5  -7847.5         3.65   3.431373
# 139     2652.5  -7347.5         2.77   2.676399
# 140     2387.5  -7612.5         3.19   2.926829
# 141     3165.0  -6835.0         2.16   2.427184
# 142     3350.0  -6650.0         1.99   2.179177
# 144     2462.5  -7537.5         3.06   7.948718
# 145     2462.5  -7537.5         3.06   6.582278
# 146     2467.5  -7532.5         3.05  10.789474
# 147     2707.5  -7292.5         2.69   3.439803
# 148     2492.5  -7507.5         3.01       5.25
# 149     2645.0  -7355.0         2.78   3.694581
# 150     2645.0  -7355.0         2.78   3.950617
# 151     2927.5  -7072.5         2.42   3.186275
# 152     3427.5  -6572.5         1.92    2.43309
# 153     3162.5  -6837.5         2.16   2.682927
# 154     3940.0  -6060.0         1.54   2.184466
# 155     4125.0  -5875.0         1.42   1.937046
# 157     3012.5  -6987.5         2.32   7.692308
# 158     3012.5  -6987.5         2.32   6.329114
# 159     3017.5  -6982.5         2.31  10.526316
# 160     3257.5  -6742.5         2.07   3.194103
# 161     3042.5  -6957.5         2.29        5.0
# 162     3195.0  -6805.0         2.13   3.448276
# 163     3195.0  -6805.0         2.13   3.703704
# 164     3477.5  -6522.5         1.88   2.941176
# 165     3977.5  -6022.5         1.51   2.189781
# 166     3712.5  -6287.5         1.69   2.439024
# 167     4490.0  -5510.0         1.23   1.941748
# 168     4675.0  -5325.0         1.14   1.694915
